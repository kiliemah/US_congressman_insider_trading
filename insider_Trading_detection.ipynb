# %% [markdown]
# # Traditional Market, crypto market and legislative authorities
# ----

# %% [markdown]
# ## 1. Installation

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -O ./spark-3.4.3-bin-hadoop3.tgz  https://dlcdn.apache.org/spark/spark-3.4.3/spark-3.4.3-bin-hadoop3.tgz

# !tar zxvf ./spark-3.4.3-bin-hadoop3.tgz
# !pip install findspark
# Out:
# --2024-07-14 11:22:16--  https://dlcdn.apache.org/spark/spark-3.4.3/spark-3.4.3-bin-hadoop3.tgz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388930980 (371M) [application/x-gzip]
# Saving to: ‘./spark-3.4.3-bin-hadoop3.tgz’
#
# ./spark-3.4.3-bin-h 100%[===================>] 370.91M   296MB/s    in 1.3s
#
# 2024-07-14 11:22:18 (296 MB/s) - ‘./spark-3.4.3-bin-hadoop3.tgz’ saved [388930980/388930980]
#
# spark-3.4.3-bin-hadoop3/
# spark-3.4.3-bin-hadoop3/R/
# spark-3.4.3-bin-hadoop3/R/lib/
# spark-3.4.3-bin-hadoop3/R/lib/sparkr.zip
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/html/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/html/R.css
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/html/00Index.html
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/worker/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/worker/worker.R
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/worker/daemon.R
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/tests/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/tests/testthat/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/tests/testthat/test_basic.R
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/profile/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/profile/shell.R
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/profile/general.R
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/doc/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/doc/index.html
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.html
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.Rmd
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/doc/sparkr-vignettes.R
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/R/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/R/SparkR
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/R/SparkR.rdx
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/R/SparkR.rdb
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/Meta/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/Meta/nsInfo.rds
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/Meta/vignette.rds
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/Meta/Rd.rds
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/Meta/features.rds
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/Meta/package.rds
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/Meta/links.rds
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/Meta/hsearch.rds
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/DESCRIPTION
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/NAMESPACE
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/INDEX
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/help/
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/help/aliases.rds
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/help/AnIndex
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/help/SparkR.rdx
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/help/SparkR.rdb
# spark-3.4.3-bin-hadoop3/R/lib/SparkR/help/paths.rds
# spark-3.4.3-bin-hadoop3/sbin/
# spark-3.4.3-bin-hadoop3/sbin/stop-slaves.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-slave.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-mesos-shuffle-service.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-mesos-dispatcher.sh
# spark-3.4.3-bin-hadoop3/sbin/start-slaves.sh
# spark-3.4.3-bin-hadoop3/sbin/start-slave.sh
# spark-3.4.3-bin-hadoop3/sbin/start-mesos-shuffle-service.sh
# spark-3.4.3-bin-hadoop3/sbin/start-mesos-dispatcher.sh
# spark-3.4.3-bin-hadoop3/sbin/start-connect-server.sh
# spark-3.4.3-bin-hadoop3/sbin/slaves.sh
# spark-3.4.3-bin-hadoop3/sbin/decommission-slave.sh
# spark-3.4.3-bin-hadoop3/sbin/workers.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-workers.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-worker.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-thriftserver.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-master.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-history-server.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-connect-server.sh
# spark-3.4.3-bin-hadoop3/sbin/stop-all.sh
# spark-3.4.3-bin-hadoop3/sbin/start-workers.sh
# spark-3.4.3-bin-hadoop3/sbin/start-worker.sh
# spark-3.4.3-bin-hadoop3/sbin/start-thriftserver.sh
# spark-3.4.3-bin-hadoop3/sbin/start-master.sh
# spark-3.4.3-bin-hadoop3/sbin/start-history-server.sh
# spark-3.4.3-bin-hadoop3/sbin/start-all.sh
# spark-3.4.3-bin-hadoop3/sbin/spark-daemons.sh
# spark-3.4.3-bin-hadoop3/sbin/spark-daemon.sh
# spark-3.4.3-bin-hadoop3/sbin/spark-config.sh
# spark-3.4.3-bin-hadoop3/sbin/decommission-worker.sh
# spark-3.4.3-bin-hadoop3/python/
# spark-3.4.3-bin-hadoop3/python/dist/
# spark-3.4.3-bin-hadoop3/python/pyspark.egg-info/
# spark-3.4.3-bin-hadoop3/python/pyspark.egg-info/SOURCES.txt
# spark-3.4.3-bin-hadoop3/python/pyspark.egg-info/top_level.txt
# spark-3.4.3-bin-hadoop3/python/pyspark.egg-info/requires.txt
# spark-3.4.3-bin-hadoop3/python/pyspark.egg-info/dependency_links.txt
# spark-3.4.3-bin-hadoop3/python/pyspark.egg-info/PKG-INFO
# spark-3.4.3-bin-hadoop3/python/setup.py
# spark-3.4.3-bin-hadoop3/python/setup.cfg
# spark-3.4.3-bin-hadoop3/python/run-tests.py
# spark-3.4.3-bin-hadoop3/python/run-tests-with-coverage
# spark-3.4.3-bin-hadoop3/python/run-tests
# spark-3.4.3-bin-hadoop3/python/mypy.ini
# spark-3.4.3-bin-hadoop3/python/README.md
# spark-3.4.3-bin-hadoop3/python/.gitignore
# spark-3.4.3-bin-hadoop3/python/lib/
# spark-3.4.3-bin-hadoop3/python/lib/pyspark.zip
# spark-3.4.3-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip
# spark-3.4.3-bin-hadoop3/python/lib/PY4J_LICENSE.txt
# spark-3.4.3-bin-hadoop3/python/docs/
# spark-3.4.3-bin-hadoop3/python/docs/Makefile
# spark-3.4.3-bin-hadoop3/python/docs/source/
# spark-3.4.3-bin-hadoop3/python/docs/source/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/conf.py
# spark-3.4.3-bin-hadoop3/python/docs/source/getting_started/
# spark-3.4.3-bin-hadoop3/python/docs/source/getting_started/quickstart_ps.ipynb
# spark-3.4.3-bin-hadoop3/python/docs/source/getting_started/quickstart_df.ipynb
# spark-3.4.3-bin-hadoop3/python/docs/source/getting_started/quickstart_connect.ipynb
# spark-3.4.3-bin-hadoop3/python/docs/source/getting_started/install.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/getting_started/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/development/
# spark-3.4.3-bin-hadoop3/python/docs/source/development/testing.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/development/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/development/debugging.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/development/contributing.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/development/setting_ide.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/_templates/
# spark-3.4.3-bin-hadoop3/python/docs/source/_templates/autosummary/
# spark-3.4.3-bin-hadoop3/python/docs/source/_templates/autosummary/class_with_docs.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/_templates/autosummary/class.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/_static/
# spark-3.4.3-bin-hadoop3/python/docs/source/_static/css/
# spark-3.4.3-bin-hadoop3/python/docs/source/_static/css/pyspark.css
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/python_packaging.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/sql/
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/sql/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/sql/arrow_pandas.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/typehints.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/transform_apply.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/options.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/best_practices.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/types.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/pandas_pyspark.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/from_to_dbms.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/pandas_on_spark/faq.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/user_guide/arrow_pandas.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.ml.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.errors.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.streaming.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.ss/
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.ss/query_management.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.ss/io.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.ss/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.ss/core_classes.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/spark_session.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/grouping.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/functions.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/dataframe.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/data_types.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/core_classes.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/column.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/window.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/udf.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/row.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/protobuf.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/observation.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/io.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/configuration.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/catalog.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.sql/avro.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.resource.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/series.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/io.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/indexing.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/groupby.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/general_functions.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/frame.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/window.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/resampling.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/ml.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.pandas/extensions.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/reference/pyspark.mllib.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/migration_guide/
# spark-3.4.3-bin-hadoop3/python/docs/source/migration_guide/pyspark_upgrade.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/migration_guide/koalas_to_pyspark.rst
# spark-3.4.3-bin-hadoop3/python/docs/source/migration_guide/index.rst
# spark-3.4.3-bin-hadoop3/python/docs/make2.bat
# spark-3.4.3-bin-hadoop3/python/docs/make.bat
# spark-3.4.3-bin-hadoop3/python/MANIFEST.in
# spark-3.4.3-bin-hadoop3/python/.coveragerc
# spark-3.4.3-bin-hadoop3/python/test_support/
# spark-3.4.3-bin-hadoop3/python/test_support/userlibrary.py
# spark-3.4.3-bin-hadoop3/python/test_support/userlib-0.1.zip
# spark-3.4.3-bin-hadoop3/python/test_support/test_pytorch_training_file.py
# spark-3.4.3-bin-hadoop3/python/test_support/sql/
# spark-3.4.3-bin-hadoop3/python/test_support/sql/text-test.txt
# spark-3.4.3-bin-hadoop3/python/test_support/sql/streaming/
# spark-3.4.3-bin-hadoop3/python/test_support/sql/streaming/text-test.txt
# spark-3.4.3-bin-hadoop3/python/test_support/sql/people_array_utf16le.json
# spark-3.4.3-bin-hadoop3/python/test_support/sql/people_array.json
# spark-3.4.3-bin-hadoop3/python/test_support/sql/people1.json
# spark-3.4.3-bin-hadoop3/python/test_support/sql/people.json
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.4.3-bin-hadoop3/python/test_support/sql/orc_partitioned/_SUCCESS
# spark-3.4.3-bin-hadoop3/python/test_support/sql/ages_newlines.csv
# spark-3.4.3-bin-hadoop3/python/test_support/hello/
# spark-3.4.3-bin-hadoop3/python/test_support/hello/sub_hello/
# spark-3.4.3-bin-hadoop3/python/test_support/hello/sub_hello/sub_hello.txt
# spark-3.4.3-bin-hadoop3/python/test_support/hello/hello.txt
# spark-3.4.3-bin-hadoop3/python/test_support/SimpleHTTPServer.py
# spark-3.4.3-bin-hadoop3/python/test_coverage/
# spark-3.4.3-bin-hadoop3/python/test_coverage/coverage_daemon.py
# spark-3.4.3-bin-hadoop3/python/test_coverage/conf/
# spark-3.4.3-bin-hadoop3/python/test_coverage/conf/spark-defaults.conf
# spark-3.4.3-bin-hadoop3/python/test_coverage/sitecustomize.py
# spark-3.4.3-bin-hadoop3/python/pyspark/
# spark-3.4.3-bin-hadoop3/python/pyspark/python/
# spark-3.4.3-bin-hadoop3/python/pyspark/python/pyspark/
# spark-3.4.3-bin-hadoop3/python/pyspark/python/pyspark/shell.py
# spark-3.4.3-bin-hadoop3/python/pyspark/__pycache__/
# spark-3.4.3-bin-hadoop3/python/pyspark/__pycache__/install.cpython-38.pyc
# spark-3.4.3-bin-hadoop3/python/pyspark/worker.py
# spark-3.4.3-bin-hadoop3/python/pyspark/version.py
# spark-3.4.3-bin-hadoop3/python/pyspark/util.py
# spark-3.4.3-bin-hadoop3/python/pyspark/traceback_utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/taskcontext.py
# spark-3.4.3-bin-hadoop3/python/pyspark/status.py
# spark-3.4.3-bin-hadoop3/python/pyspark/join.py
# spark-3.4.3-bin-hadoop3/python/pyspark/java_gateway.py
# spark-3.4.3-bin-hadoop3/python/pyspark/instrumentation_utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/install.py
# spark-3.4.3-bin-hadoop3/python/pyspark/files.py
# spark-3.4.3-bin-hadoop3/python/pyspark/daemon.py
# spark-3.4.3-bin-hadoop3/python/pyspark/context.py
# spark-3.4.3-bin-hadoop3/python/pyspark/conf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/broadcast.py
# spark-3.4.3-bin-hadoop3/python/pyspark/accumulators.py
# spark-3.4.3-bin-hadoop3/python/pyspark/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/shuffle.py
# spark-3.4.3-bin-hadoop3/python/pyspark/shell.py
# spark-3.4.3-bin-hadoop3/python/pyspark/serializers.py
# spark-3.4.3-bin-hadoop3/python/pyspark/rdd.py
# spark-3.4.3-bin-hadoop3/python/pyspark/profiler.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/dataframe.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/context.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/conf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/column.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/window.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/udf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/types.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/sql_formatter.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/session.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/readwriter.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/observation.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/group.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/catalog.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/_typing.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/window.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/udf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/types.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/session.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/readwriter.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/plan.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/group.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/expressions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/dataframe.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/conversion.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/conf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/column.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/client.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/catalog.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/_typing.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/types_pb2.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/types_pb2.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/relations_pb2.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/relations_pb2.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/expressions_pb2.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/expressions_pb2.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/example_plugins_pb2.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/common_pb2.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/common_pb2.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/commands_pb2.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/commands_pb2.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/catalog_pb2.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/catalog_pb2.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/base_pb2_grpc.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/base_pb2.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/base_pb2.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/example_plugins_pb2.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/proto/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/connect/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/avro/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/avro/functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/avro/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_udf_profiler.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_udf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_types.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_session.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_readwriter.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_group.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_datasources.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_dataframe.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_conf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_column.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_catalog.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_arrow_python_udf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_arrow_map.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_arrow.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/typing/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/typing/test_session.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/typing/test_readwriter.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/typing/test_functions.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/typing/test_dataframe.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/typing/test_udf.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/typing/test_column.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_serde.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_pandas_sqlmetrics.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_errors.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/test_context.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/streaming/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming_listener.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/streaming/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_window.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_typehints.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_scalar.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_grouped_agg.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_map.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_grouped_map_with_state.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_grouped_map.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_cogrouped_map.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_typehints_with_future_annotations.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/pandas/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_udf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_types.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_readwriter.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_udf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_map.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_grouped_map.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_cogrouped_map.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_datasources.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_dataframe.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_column.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_arrow.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_connect_plan.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_connect_function.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_connect_column.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_connect_basic.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_client.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_serde.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_group.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_errors.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_conf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_catalog.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_arrow_map.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/connect/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/streaming/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/streaming/state.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/streaming/readwriter.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/streaming/query.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/streaming/listener.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/streaming/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/protobuf/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/protobuf/functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/protobuf/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/types.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/typehints.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/serializers.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/map_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/group_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/functions.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/conversion.py
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/_typing/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/_typing/__init__.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/series.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/frame.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/__init__.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/sql/pandas/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/resultiterable.py
# spark-3.4.3-bin-hadoop3/python/pyspark/resource/
# spark-3.4.3-bin-hadoop3/python/pyspark/resource/requests.py
# spark-3.4.3-bin-hadoop3/python/pyspark/resource/profile.py
# spark-3.4.3-bin-hadoop3/python/pyspark/resource/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/resource/tests/test_resources.py
# spark-3.4.3-bin-hadoop3/python/pyspark/resource/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/resource/information.py
# spark-3.4.3-bin-hadoop3/python/pyspark/resource/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/rddsampler.py
# spark-3.4.3-bin-hadoop3/python/pyspark/py.typed
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/groupby.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/generic.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/frame.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/exceptions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/datetimes.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/correlation.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/config.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/categorical.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/base.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/accessors.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/_typing.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/window.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/supported_api_gen.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/strings.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/sql_processor.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/sql_formatter.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/series.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/resample.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/numpy_compat.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/namespace.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/mlflow.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/internal.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexing.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/usage_logging/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/usage_logging/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/usage_logging/usage_logger.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/typedef/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/typedef/typehints.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/typedef/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/extensions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/timedelta_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/string_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/num_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/null_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/datetime_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/date_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/categorical_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/boolean_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/binary_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/base.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/udt_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/complex_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/data_type_ops/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_window.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_typedef.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_stats.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_sql.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_spark_functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_series_string.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_series_datetime.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_series_conversion.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_series.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_scalars.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_rolling.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_reshape.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_resample.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_repr.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames_slow.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames_groupby_rolling.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames_groupby_expanding.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames_groupby.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_numpy_compat.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_namespace.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_internal.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_indexops_spark.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_indexing.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_groupby_slow.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_groupby.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_generic_functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_frame_spark.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_extension.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_expanding.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_ewm.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_default_index.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe_spark_io.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe_slow.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe_conversion.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_csv.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_config.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/test_categorical.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/testing_utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_udt_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_timedelta_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_string_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_num_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_null_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_datetime_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_date_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_complex_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_categorical_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_boolean_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_binary_ops.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_base.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/plot/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/plot/test_series_plot_plotly.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/plot/test_series_plot_matplotlib.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/plot/test_series_plot.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/plot/test_frame_plot_plotly.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/plot/test_frame_plot_matplotlib.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/plot/test_frame_plot.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/plot/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/indexes/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_timedelta.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_datetime.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_category.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_base.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/indexes/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/spark/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/spark/functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/spark/accessors.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/spark/utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/spark/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/plot/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/plot/matplotlib.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/plot/core.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/plot/plotly.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/plot/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/series.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/groupby.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/frame.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/window.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/scalars.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/resample.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/indexes.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/general_functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/common.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/missing/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexes/
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexes/timedelta.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexes/numeric.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexes/multi.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexes/datetimes.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexes/category.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexes/base.py
# spark-3.4.3-bin-hadoop3/python/pyspark/pandas/indexes/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/util.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tree.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/regression.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/recommendation.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/random.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/fpm.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/feature.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/evaluation.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/common.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/clustering.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/classification.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/_typing.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tests/test_streaming_algorithms.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tests/test_stat.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tests/test_linalg.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tests/test_feature.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tests/test_algorithms.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tests/test_util.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/stat/
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/stat/_statistics.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/stat/KernelDensity.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/stat/test.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/stat/distribution.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/stat/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/linalg/
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/linalg/distributed.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/linalg/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/mllib/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/wrapper.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/util.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tuning.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tree.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/stat.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/regression.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/recommendation.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/pipeline.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/image.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/fpm.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/feature.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/evaluation.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/common.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/clustering.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/classification.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/base.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/_typing.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/log_communication.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/distributor.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/torch_run_process_wrapper.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/tests/test_log_communication.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/tests/test_distributor.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/torch/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_wrapper.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_tuning.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_model_cache.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_linalg.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_image.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_functions.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_feature.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_algorithms.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/typing/
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/typing/test_feature.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/typing/test_evaluation.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/typing/test_clustering.yaml
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/typing/test_classification.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/typing/test_regression.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/typing/test_readable.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/typing/test_param.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_util.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_training_summary.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_stat.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_pipeline.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_persistence.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_param.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_evaluation.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/test_base.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/param/
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/param/shared.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/param/_shared_params_code_gen.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/param/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/model_cache.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/linalg/
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/linalg/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/ml/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/find_spark_home.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/error_classes.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/tests/test_errors.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/exceptions/
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/exceptions/connect.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/exceptions/captured.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/exceptions/base.py
# spark-3.4.3-bin-hadoop3/python/pyspark/errors/exceptions/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/cloudpickle/
# spark-3.4.3-bin-hadoop3/python/pyspark/cloudpickle/cloudpickle_fast.py
# spark-3.4.3-bin-hadoop3/python/pyspark/cloudpickle/cloudpickle.py
# spark-3.4.3-bin-hadoop3/python/pyspark/cloudpickle/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/cloudpickle/compat.py
# spark-3.4.3-bin-hadoop3/python/pyspark/_typing.pyi
# spark-3.4.3-bin-hadoop3/python/pyspark/_globals.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_worker.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_util.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_taskcontext.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_statcounter.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_shuffle.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_profiler.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_pin_thread.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_memory_profiler.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_install_spark.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_context.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/typing/
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/typing/test_rdd.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/typing/test_resultiterable.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/typing/test_core.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/typing/test_context.yml
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_stage_sched.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_serializers.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_readwrite.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_rddsampler.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_rddbarrier.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_rdd.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_join.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_daemon.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_conf.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_broadcast.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/test_appsubmit.py
# spark-3.4.3-bin-hadoop3/python/pyspark/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/utils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/streamingutils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/sqlutils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/pandasutils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/mlutils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/connectutils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/testing/mllibutils.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/dstream.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/context.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/util.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/tests/
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/tests/test_listener.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/tests/test_dstream.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/tests/test_context.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/tests/test_kinesis.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/tests/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/listener.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/kinesis.py
# spark-3.4.3-bin-hadoop3/python/pyspark/streaming/__init__.py
# spark-3.4.3-bin-hadoop3/python/pyspark/storagelevel.py
# spark-3.4.3-bin-hadoop3/python/pyspark/statcounter.py
# spark-3.4.3-bin-hadoop3/bin/
# spark-3.4.3-bin-hadoop3/bin/pyspark
# spark-3.4.3-bin-hadoop3/bin/load-spark-env.sh
# spark-3.4.3-bin-hadoop3/bin/load-spark-env.cmd
# spark-3.4.3-bin-hadoop3/bin/sparkR2.cmd
# spark-3.4.3-bin-hadoop3/bin/sparkR.cmd
# spark-3.4.3-bin-hadoop3/bin/sparkR
# spark-3.4.3-bin-hadoop3/bin/spark-submit2.cmd
# spark-3.4.3-bin-hadoop3/bin/spark-submit.cmd
# spark-3.4.3-bin-hadoop3/bin/spark-submit
# spark-3.4.3-bin-hadoop3/bin/spark-sql2.cmd
# spark-3.4.3-bin-hadoop3/bin/spark-sql.cmd
# spark-3.4.3-bin-hadoop3/bin/spark-sql
# spark-3.4.3-bin-hadoop3/bin/spark-shell2.cmd
# spark-3.4.3-bin-hadoop3/bin/spark-shell.cmd
# spark-3.4.3-bin-hadoop3/bin/spark-shell
# spark-3.4.3-bin-hadoop3/bin/spark-connect-shell
# spark-3.4.3-bin-hadoop3/bin/spark-class2.cmd
# spark-3.4.3-bin-hadoop3/bin/spark-class.cmd
# spark-3.4.3-bin-hadoop3/bin/spark-class
# spark-3.4.3-bin-hadoop3/bin/run-example.cmd
# spark-3.4.3-bin-hadoop3/bin/run-example
# spark-3.4.3-bin-hadoop3/bin/pyspark2.cmd
# spark-3.4.3-bin-hadoop3/bin/pyspark.cmd
# spark-3.4.3-bin-hadoop3/bin/find-spark-home.cmd
# spark-3.4.3-bin-hadoop3/bin/find-spark-home
# spark-3.4.3-bin-hadoop3/bin/docker-image-tool.sh
# spark-3.4.3-bin-hadoop3/bin/beeline.cmd
# spark-3.4.3-bin-hadoop3/bin/beeline
# ...
# spark-3.4.3-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaSparkPi.java
# spark-3.4.3-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaPageRank.java
# spark-3.4.3-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaLogQuery.java
# spark-3.4.3-bin-hadoop3/examples/src/main/java/org/apache/spark/examples/JavaHdfsLR.java
# spark-3.4.3-bin-hadoop3/examples/src/main/scripts/
# spark-3.4.3-bin-hadoop3/examples/src/main/scripts/getGpusResources.sh
# spark-3.4.3-bin-hadoop3/examples/jars/
# spark-3.4.3-bin-hadoop3/examples/jars/spark-examples_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/examples/jars/scopt_2.12-3.7.1.jar
# spark-3.4.3-bin-hadoop3/kubernetes/
# spark-3.4.3-bin-hadoop3/kubernetes/tests/
# spark-3.4.3-bin-hadoop3/kubernetes/tests/worker_memory_check.py
# spark-3.4.3-bin-hadoop3/kubernetes/tests/python_executable_check.py
# spark-3.4.3-bin-hadoop3/kubernetes/tests/pyfiles.py
# spark-3.4.3-bin-hadoop3/kubernetes/tests/py_container_checks.py
# spark-3.4.3-bin-hadoop3/kubernetes/tests/decommissioning_cleanup.py
# spark-3.4.3-bin-hadoop3/kubernetes/tests/decommissioning.py
# spark-3.4.3-bin-hadoop3/kubernetes/tests/autoscale.py
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/entrypoint.sh
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/Dockerfile
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/decom.sh
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/python/
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/python/Dockerfile
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/R/
# spark-3.4.3-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/R/Dockerfile
# spark-3.4.3-bin-hadoop3/yarn/
# spark-3.4.3-bin-hadoop3/yarn/spark-3.4.3-yarn-shuffle.jar
# spark-3.4.3-bin-hadoop3/jars/
# spark-3.4.3-bin-hadoop3/jars/zstd-jni-1.5.2-5.jar
# spark-3.4.3-bin-hadoop3/jars/zookeeper-jute-3.6.3.jar
# spark-3.4.3-bin-hadoop3/jars/zookeeper-3.6.3.jar
# spark-3.4.3-bin-hadoop3/jars/zjsonpatch-0.3.0.jar
# spark-3.4.3-bin-hadoop3/jars/xz-1.9.jar
# spark-3.4.3-bin-hadoop3/jars/xbean-asm9-shaded-4.22.jar
# spark-3.4.3-bin-hadoop3/jars/univocity-parsers-2.9.1.jar
# spark-3.4.3-bin-hadoop3/jars/transaction-api-1.1.jar
# spark-3.4.3-bin-hadoop3/jars/tink-1.7.0.jar
# spark-3.4.3-bin-hadoop3/jars/threeten-extra-1.7.1.jar
# spark-3.4.3-bin-hadoop3/jars/super-csv-2.2.0.jar
# spark-3.4.3-bin-hadoop3/jars/stream-2.9.6.jar
# spark-3.4.3-bin-hadoop3/jars/stax-api-1.0.1.jar
# spark-3.4.3-bin-hadoop3/jars/spire_2.12-0.17.0.jar
# spark-3.4.3-bin-hadoop3/jars/spire-util_2.12-0.17.0.jar
# spark-3.4.3-bin-hadoop3/jars/spire-platform_2.12-0.17.0.jar
# spark-3.4.3-bin-hadoop3/jars/spire-macros_2.12-0.17.0.jar
# spark-3.4.3-bin-hadoop3/jars/spark-yarn_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-unsafe_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-tags_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-streaming_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-sql_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-sketch_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-repl_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-network-shuffle_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-network-common_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-mllib_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-mllib-local_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-mesos_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-launcher_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-kvstore_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-kubernetes_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-hive_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-hive-thriftserver_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-graphx_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-core_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/spark-catalyst_2.12-3.4.3.jar
# spark-3.4.3-bin-hadoop3/jars/snappy-java-1.1.10.5.jar
# spark-3.4.3-bin-hadoop3/jars/snakeyaml-1.33.jar
# spark-3.4.3-bin-hadoop3/jars/slf4j-api-2.0.6.jar
# spark-3.4.3-bin-hadoop3/jars/shims-0.9.38.jar
# spark-3.4.3-bin-hadoop3/jars/scala-xml_2.12-2.1.0.jar
# spark-3.4.3-bin-hadoop3/jars/scala-reflect-2.12.17.jar
# spark-3.4.3-bin-hadoop3/jars/scala-parser-combinators_2.12-2.1.1.jar
# spark-3.4.3-bin-hadoop3/jars/scala-library-2.12.17.jar
# spark-3.4.3-bin-hadoop3/jars/scala-compiler-2.12.17.jar
# spark-3.4.3-bin-hadoop3/jars/scala-collection-compat_2.12-2.7.0.jar
# spark-3.4.3-bin-hadoop3/jars/rocksdbjni-7.9.2.jar
# spark-3.4.3-bin-hadoop3/jars/py4j-0.10.9.7.jar
# spark-3.4.3-bin-hadoop3/jars/protobuf-java-2.5.0.jar
# spark-3.4.3-bin-hadoop3/jars/pickle-1.3.jar
# spark-3.4.3-bin-hadoop3/jars/parquet-jackson-1.12.3.jar
# spark-3.4.3-bin-hadoop3/jars/parquet-hadoop-1.12.3.jar
# spark-3.4.3-bin-hadoop3/jars/parquet-format-structures-1.12.3.jar
# spark-3.4.3-bin-hadoop3/jars/parquet-encoding-1.12.3.jar
# spark-3.4.3-bin-hadoop3/jars/parquet-common-1.12.3.jar
# spark-3.4.3-bin-hadoop3/jars/parquet-column-1.12.3.jar
# spark-3.4.3-bin-hadoop3/jars/paranamer-2.8.jar
# spark-3.4.3-bin-hadoop3/jars/osgi-resource-locator-1.0.3.jar
# spark-3.4.3-bin-hadoop3/jars/oro-2.0.8.jar
# spark-3.4.3-bin-hadoop3/jars/orc-shims-1.8.7.jar
# spark-3.4.3-bin-hadoop3/jars/orc-mapreduce-1.8.7-shaded-protobuf.jar
# spark-3.4.3-bin-hadoop3/jars/orc-core-1.8.7-shaded-protobuf.jar
# spark-3.4.3-bin-hadoop3/jars/opencsv-2.3.jar
# spark-3.4.3-bin-hadoop3/jars/okio-1.15.0.jar
# spark-3.4.3-bin-hadoop3/jars/okhttp-3.12.12.jar
# spark-3.4.3-bin-hadoop3/jars/objenesis-3.2.jar
# spark-3.4.3-bin-hadoop3/jars/netty-transport-native-unix-common-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-transport-native-kqueue-4.1.87.Final-osx-x86_64.jar
# spark-3.4.3-bin-hadoop3/jars/netty-transport-native-kqueue-4.1.87.Final-osx-aarch_64.jar
# spark-3.4.3-bin-hadoop3/jars/netty-transport-native-epoll-4.1.87.Final-linux-x86_64.jar
# spark-3.4.3-bin-hadoop3/jars/netty-transport-native-epoll-4.1.87.Final-linux-aarch_64.jar
# spark-3.4.3-bin-hadoop3/jars/netty-transport-classes-kqueue-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-transport-classes-epoll-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-transport-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-resolver-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-handler-proxy-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-handler-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-common-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-codec-socks-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-codec-http2-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-codec-http-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-codec-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-buffer-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/netty-all-4.1.87.Final.jar
# spark-3.4.3-bin-hadoop3/jars/minlog-1.3.0.jar
# spark-3.4.3-bin-hadoop3/jars/metrics-jvm-4.2.15.jar
# spark-3.4.3-bin-hadoop3/jars/metrics-json-4.2.15.jar
# spark-3.4.3-bin-hadoop3/jars/metrics-jmx-4.2.15.jar
# spark-3.4.3-bin-hadoop3/jars/metrics-graphite-4.2.15.jar
# spark-3.4.3-bin-hadoop3/jars/metrics-core-4.2.15.jar
# spark-3.4.3-bin-hadoop3/jars/mesos-1.4.3-shaded-protobuf.jar
# spark-3.4.3-bin-hadoop3/jars/lz4-java-1.8.0.jar
# spark-3.4.3-bin-hadoop3/jars/logging-interceptor-3.12.12.jar
# spark-3.4.3-bin-hadoop3/jars/log4j-slf4j2-impl-2.19.0.jar
# spark-3.4.3-bin-hadoop3/jars/log4j-core-2.19.0.jar
# spark-3.4.3-bin-hadoop3/jars/log4j-api-2.19.0.jar
# spark-3.4.3-bin-hadoop3/jars/log4j-1.2-api-2.19.0.jar
# spark-3.4.3-bin-hadoop3/jars/libthrift-0.12.0.jar
# spark-3.4.3-bin-hadoop3/jars/libfb303-0.9.3.jar
# spark-3.4.3-bin-hadoop3/jars/leveldbjni-all-1.8.jar
# spark-3.4.3-bin-hadoop3/jars/lapack-3.0.3.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-storageclass-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-scheduling-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-rbac-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-policy-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-node-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-networking-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-metrics-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-gatewayapi-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-flowcontrol-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-extensions-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-events-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-discovery-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-core-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-coordination-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-common-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-certificates-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-batch-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-autoscaling-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-apps-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-apiextensions-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-model-admissionregistration-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-httpclient-okhttp-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-client-api-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kubernetes-client-6.4.1.jar
# spark-3.4.3-bin-hadoop3/jars/kryo-shaded-4.0.2.jar
# spark-3.4.3-bin-hadoop3/jars/jul-to-slf4j-2.0.6.jar
# spark-3.4.3-bin-hadoop3/jars/jta-1.1.jar
# spark-3.4.3-bin-hadoop3/jars/jsr305-3.0.0.jar
# spark-3.4.3-bin-hadoop3/jars/json4s-scalap_2.12-3.7.0-M11.jar
# spark-3.4.3-bin-hadoop3/jars/json4s-jackson_2.12-3.7.0-M11.jar
# spark-3.4.3-bin-hadoop3/jars/json4s-core_2.12-3.7.0-M11.jar
# spark-3.4.3-bin-hadoop3/jars/json4s-ast_2.12-3.7.0-M11.jar
# spark-3.4.3-bin-hadoop3/jars/json-1.8.jar
# spark-3.4.3-bin-hadoop3/jars/jpam-1.1.jar
# spark-3.4.3-bin-hadoop3/jars/jodd-core-3.5.2.jar
# spark-3.4.3-bin-hadoop3/jars/joda-time-2.12.2.jar
# spark-3.4.3-bin-hadoop3/jars/jline-2.14.6.jar
# spark-3.4.3-bin-hadoop3/jars/jersey-server-2.36.jar
# spark-3.4.3-bin-hadoop3/jars/jersey-hk2-2.36.jar
# spark-3.4.3-bin-hadoop3/jars/jersey-container-servlet-core-2.36.jar
# spark-3.4.3-bin-hadoop3/jars/jersey-container-servlet-2.36.jar
# spark-3.4.3-bin-hadoop3/jars/jersey-common-2.36.jar
# spark-3.4.3-bin-hadoop3/jars/jersey-client-2.36.jar
# spark-3.4.3-bin-hadoop3/jars/jdo-api-3.0.1.jar
# spark-3.4.3-bin-hadoop3/jars/jcl-over-slf4j-2.0.6.jar
# spark-3.4.3-bin-hadoop3/jars/jaxb-runtime-2.3.2.jar
# spark-3.4.3-bin-hadoop3/jars/javolution-5.5.1.jar
# spark-3.4.3-bin-hadoop3/jars/javax.jdo-3.2.0-m3.jar
# spark-3.4.3-bin-hadoop3/jars/javassist-3.25.0-GA.jar
# spark-3.4.3-bin-hadoop3/jars/janino-3.1.9.jar
# spark-3.4.3-bin-hadoop3/jars/jakarta.xml.bind-api-2.3.2.jar
# spark-3.4.3-bin-hadoop3/jars/jakarta.ws.rs-api-2.1.6.jar
# spark-3.4.3-bin-hadoop3/jars/jakarta.validation-api-2.0.2.jar
# spark-3.4.3-bin-hadoop3/jars/jakarta.servlet-api-4.0.3.jar
# spark-3.4.3-bin-hadoop3/jars/jakarta.inject-2.6.1.jar
# spark-3.4.3-bin-hadoop3/jars/jakarta.annotation-api-1.3.5.jar
# spark-3.4.3-bin-hadoop3/jars/jackson-module-scala_2.12-2.14.2.jar
# spark-3.4.3-bin-hadoop3/jars/jackson-mapper-asl-1.9.13.jar
# spark-3.4.3-bin-hadoop3/jars/jackson-datatype-jsr310-2.14.2.jar
# spark-3.4.3-bin-hadoop3/jars/jackson-dataformat-yaml-2.14.2.jar
# spark-3.4.3-bin-hadoop3/jars/jackson-databind-2.14.2.jar
# spark-3.4.3-bin-hadoop3/jars/jackson-core-asl-1.9.13.jar
# spark-3.4.3-bin-hadoop3/jars/jackson-core-2.14.2.jar
# spark-3.4.3-bin-hadoop3/jars/jackson-annotations-2.14.2.jar
# spark-3.4.3-bin-hadoop3/jars/ivy-2.5.1.jar
# spark-3.4.3-bin-hadoop3/jars/istack-commons-runtime-3.0.8.jar
# spark-3.4.3-bin-hadoop3/jars/httpcore-4.4.16.jar
# spark-3.4.3-bin-hadoop3/jars/httpclient-4.5.14.jar
# spark-3.4.3-bin-hadoop3/jars/hk2-utils-2.6.1.jar
# spark-3.4.3-bin-hadoop3/jars/hk2-locator-2.6.1.jar
# spark-3.4.3-bin-hadoop3/jars/hk2-api-2.6.1.jar
# spark-3.4.3-bin-hadoop3/jars/hive-storage-api-2.8.1.jar
# spark-3.4.3-bin-hadoop3/jars/hive-shims-scheduler-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-shims-common-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-shims-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-shims-0.23-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-service-rpc-3.1.3.jar
# spark-3.4.3-bin-hadoop3/jars/hive-serde-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-metastore-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-llap-common-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-jdbc-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-exec-2.3.9-core.jar
# spark-3.4.3-bin-hadoop3/jars/hive-common-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-cli-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hive-beeline-2.3.9.jar
# spark-3.4.3-bin-hadoop3/jars/hadoop-yarn-server-web-proxy-3.3.4.jar
# spark-3.4.3-bin-hadoop3/jars/hadoop-shaded-guava-1.1.1.jar
# spark-3.4.3-bin-hadoop3/jars/hadoop-client-runtime-3.3.4.jar
# spark-3.4.3-bin-hadoop3/jars/hadoop-client-api-3.3.4.jar
# spark-3.4.3-bin-hadoop3/jars/guava-14.0.1.jar
# spark-3.4.3-bin-hadoop3/jars/gson-2.2.4.jar
# spark-3.4.3-bin-hadoop3/jars/flatbuffers-java-1.12.0.jar
# spark-3.4.3-bin-hadoop3/jars/dropwizard-metrics-hadoop-metrics2-reporter-0.1.2.jar
# spark-3.4.3-bin-hadoop3/jars/derby-10.14.2.0.jar
# spark-3.4.3-bin-hadoop3/jars/datanucleus-rdbms-4.1.19.jar
# spark-3.4.3-bin-hadoop3/jars/datanucleus-core-4.1.17.jar
# spark-3.4.3-bin-hadoop3/jars/datanucleus-api-jdo-4.2.4.jar
# spark-3.4.3-bin-hadoop3/jars/curator-recipes-2.13.0.jar
# spark-3.4.3-bin-hadoop3/jars/curator-framework-2.13.0.jar
# spark-3.4.3-bin-hadoop3/jars/curator-client-2.13.0.jar
# spark-3.4.3-bin-hadoop3/jars/compress-lzf-1.1.2.jar
# spark-3.4.3-bin-hadoop3/jars/commons-text-1.10.0.jar
# spark-3.4.3-bin-hadoop3/jars/commons-pool-1.5.4.jar
# spark-3.4.3-bin-hadoop3/jars/commons-math3-3.6.1.jar
# spark-3.4.3-bin-hadoop3/jars/commons-logging-1.1.3.jar
# spark-3.4.3-bin-hadoop3/jars/commons-lang3-3.12.0.jar
# spark-3.4.3-bin-hadoop3/jars/commons-lang-2.6.jar
# spark-3.4.3-bin-hadoop3/jars/commons-io-2.11.0.jar
# spark-3.4.3-bin-hadoop3/jars/commons-dbcp-1.4.jar
# spark-3.4.3-bin-hadoop3/jars/commons-crypto-1.1.0.jar
# spark-3.4.3-bin-hadoop3/jars/commons-compress-1.22.jar
# spark-3.4.3-bin-hadoop3/jars/commons-compiler-3.1.9.jar
# spark-3.4.3-bin-hadoop3/jars/commons-collections4-4.4.jar
# spark-3.4.3-bin-hadoop3/jars/commons-collections-3.2.2.jar
# spark-3.4.3-bin-hadoop3/jars/commons-codec-1.15.jar
# spark-3.4.3-bin-hadoop3/jars/commons-cli-1.5.0.jar
# spark-3.4.3-bin-hadoop3/jars/chill_2.12-0.10.0.jar
# spark-3.4.3-bin-hadoop3/jars/chill-java-0.10.0.jar
# spark-3.4.3-bin-hadoop3/jars/cats-kernel_2.12-2.1.1.jar
# spark-3.4.3-bin-hadoop3/jars/breeze_2.12-2.1.0.jar
# spark-3.4.3-bin-hadoop3/jars/breeze-macros_2.12-2.1.0.jar
# spark-3.4.3-bin-hadoop3/jars/bonecp-0.8.0.RELEASE.jar
# spark-3.4.3-bin-hadoop3/jars/blas-3.0.3.jar
# spark-3.4.3-bin-hadoop3/jars/avro-mapred-1.11.1.jar
# spark-3.4.3-bin-hadoop3/jars/avro-ipc-1.11.1.jar
# spark-3.4.3-bin-hadoop3/jars/avro-1.11.1.jar
# spark-3.4.3-bin-hadoop3/jars/audience-annotations-0.5.0.jar
# spark-3.4.3-bin-hadoop3/jars/arrow-vector-11.0.0.jar
# spark-3.4.3-bin-hadoop3/jars/arrow-memory-netty-11.0.0.jar
# spark-3.4.3-bin-hadoop3/jars/arrow-memory-core-11.0.0.jar
# spark-3.4.3-bin-hadoop3/jars/arrow-format-11.0.0.jar
# spark-3.4.3-bin-hadoop3/jars/arpack_combined_all-0.1.jar
# spark-3.4.3-bin-hadoop3/jars/arpack-3.0.3.jar
# spark-3.4.3-bin-hadoop3/jars/aopalliance-repackaged-2.6.1.jar
# spark-3.4.3-bin-hadoop3/jars/antlr4-runtime-4.9.3.jar
# spark-3.4.3-bin-hadoop3/jars/antlr-runtime-3.5.2.jar
# spark-3.4.3-bin-hadoop3/jars/annotations-17.0.0.jar
# spark-3.4.3-bin-hadoop3/jars/algebra_2.12-2.0.1.jar
# spark-3.4.3-bin-hadoop3/jars/aircompressor-0.21.jar
# spark-3.4.3-bin-hadoop3/jars/activation-1.1.1.jar
# spark-3.4.3-bin-hadoop3/jars/ST4-4.0.4.jar
# spark-3.4.3-bin-hadoop3/jars/RoaringBitmap-0.9.38.jar
# spark-3.4.3-bin-hadoop3/jars/JTransforms-3.1.jar
# spark-3.4.3-bin-hadoop3/jars/JLargeArrays-1.5.jar
# spark-3.4.3-bin-hadoop3/jars/HikariCP-2.5.1.jar
# spark-3.4.3-bin-hadoop3/RELEASE
# Requirement already satisfied: findspark in /usr/local/lib/python3.10/dist-packages (2.0.1)

# %%
# !pip install pyspark-dbscan
# Out:
# Collecting pyspark-dbscan
#   Using cached pyspark_dbscan-1.0.6-py3-none-any.whl (3.4 kB)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from pyspark-dbscan) (1.25.2)
# Collecting pyspark>=3.1.0 (from pyspark-dbscan)
#   Using cached pyspark-3.5.1.tar.gz (317.0 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from pyspark-dbscan) (1.11.4)
# Collecting sklearn==0.0 (from pyspark-dbscan)
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn==0.24.2 (from pyspark-dbscan)
#   Using cached scikit-learn-0.24.2.tar.gz (7.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.3-bin-hadoop3"
import findspark
findspark.init()

# %%
print(os.path.exists("/usr/lib/jvm/java-8-openjdk-amd64"))  # Should print: True
print(os.path.exists("/content/spark-3.4.3-bin-hadoop3"))   # Should print: True
# Out:
# True
# True

# %%
#setting up Kaggle
# !pip install kaggle
import json

# !mkdir /root/.kaggle/
# !mv .kaggle /root/


# Installing the Kaggle package

import random


import pyspark
from pyspark.sql import SparkSession, types, functions
from datetime import datetime
import datetime
from dateutil.parser import parse

#Important Note: complete this with your own key - after running this for the first time remmember to **remove** your API_KEY
#api_token = {"username":"<Insert Your Kaggle User Name>","key":"<Insert Your Kaggle API key>"}
api_token = {"username":"kiliemahouattara","key":"52190173370a1d098d932dca433f9304"}

# creating kaggle.json file with the personal API-Key details
# You can also put this file on your Google Drive

with open('/root/.kaggle/kaggle.json', 'w') as file:
  json.dump(api_token, file)
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.7.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)
# mkdir: cannot create directory ‘/root/.kaggle/’: File exists
# mv: cannot stat '.kaggle': No such file or directory

# %% [markdown]
# ## 2. PySpark test

# %% [markdown]
# Let's start checking if PySpark works by running the following code that calculates $\pi$:

# %%
# SparkContext  is the entry point to the services of Apache Spark (execution engine)
sc = pyspark.SparkContext("local", appName="CalcPi")
def inside(p):
    x, y = random.random(), random.random()
    return x*x + y*y < 1

NUM_SAMPLES  = 1000000
count = sc.parallelize(range(0, NUM_SAMPLES)) \
             .filter(inside).count()
print(f"Pi is roughly {(4.0 * count / NUM_SAMPLES)}")

sc.stop()
# Out:
# Pi is roughly 3.141268

# %% [markdown]
# ## 3. Data collection

# %% [markdown]
# **Data links :**
# > S&P 500 data: https://www.kaggle.com/datasets/myungchankim/sp-500-daily-data-19281230-to-20210919
# <br> US congres investments: https://www.kaggle.com/datasets/heresjohnnyv/congress-investments <br>
# > bitcoin data: https://www.kaggle.com/datasets/varpit94/bitcoin-data-updated-till-26jun2021

# %%
import kaggle
# !mkdir ./datasets
# !mkdir ./datasets/dickens

# Authenticate with Kaggle
kaggle.api.authenticate()

# Download the dataset
kaggle.api.dataset_download_files('myungchankim/sp-500-daily-data-19281230-to-20210919', path='./datasets/', unzip=True)
kaggle.api.dataset_download_files('heresjohnnyv/congress-investments', path='./datasets/', unzip=True)
kaggle.api.dataset_download_files('varpit94/bitcoin-data-updated-till-26jun2021', path='./datasets/', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/myungchankim/sp-500-daily-data-19281230-to-20210919
# Dataset URL: https://www.kaggle.com/datasets/heresjohnnyv/congress-investments
# Dataset URL: https://www.kaggle.com/datasets/varpit94/bitcoin-data-updated-till-26jun2021

# %%
#Storing dataset path
spx_path = "./datasets/SPX_500_Data.csv"
btc_path = "./datasets/BTC-USD.csv"
authorities_path = "./datasets/SenatorCleaned.csv"

#Creating SparkContext object connected to the localhost
sc = pyspark.SparkContext("local", appName="Market&Authorities")

# %%
#Creating spark session
spark = SparkSession.builder.appName("Market&Authorities").getOrCreate()

# Read the 3 CSV files into 3 DataFrames
spx_df = spark.read.csv(spx_path, header=True, inferSchema=True)
btc_df = spark.read.csv(btc_path, header=True, inferSchema=True)
authorities_df = spark.read.csv(authorities_path, header=True, inferSchema=True, sep=',',  multiLine=True)\
        .withColumnRenamed('_c0', 'Index')\
        .withColumnRenamed('Transaction.Date', 'Date')\
        .withColumnRenamed('Asset.Name', 'Asset_Name')\
        .withColumnRenamed('Asset.Type', 'Asset_Type')\
        .withColumnRenamed('Type', 'Transaction_Type')

# %% [markdown]
# ## 4. Data preprocessing

# %% [markdown]
# ### 4.1. Schema processing

# %%
# Preprocessing S&P 500 historical data

# reformationg S&P 500 date column
spx_df = spx_df.withColumn("Date", functions.to_date(spx_df["Date"], 'yyyy-MM-dd'))

# Displaying S&P 500 historical data
spx_df.printSchema()
spx_df.show()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Adj Close: double (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- % Gain/Loss (Close): double (nullable = true)
#  |-- % Price Variation: double (nullable = true)
#
# +----------+-----+-----+-----+-----+---------+------+-------------------+-----------------+
# |      Date| Open| High|  Low|Close|Adj Close|Volume|% Gain/Loss (Close)|% Price Variation|
# +----------+-----+-----+-----+-----+---------+------+-------------------+-----------------+
# |1927-12-30|17.66|17.66|17.66|17.66|    17.66|     0|                0.0|              0.0|
# |1928-01-03|17.76|17.76|17.76|17.76|    17.76|     0|             0.5631|              0.0|
# |1928-01-04|17.72|17.72|17.72|17.72|    17.72|     0|            -0.2257|              0.0|
# |1928-01-05|17.55|17.55|17.55|17.55|    17.55|     0|            -0.9687|              0.0|
# |1928-01-09| 17.5| 17.5| 17.5| 17.5|     17.5|     0|            -0.2857|              0.0|
# |1928-01-10|17.37|17.37|17.37|17.37|    17.37|     0|            -0.7484|              0.0|
# |1928-01-11|17.35|17.35|17.35|17.35|    17.35|     0|            -0.1153|              0.0|
# |1928-01-12|17.47|17.47|17.47|17.47|    17.47|     0|             0.6869|              0.0|
# |1928-01-13|17.58|17.58|17.58|17.58|    17.58|     0|             0.6257|              0.0|
# |1928-01-16|17.29|17.29|17.29|17.29|    17.29|     0|            -1.6773|              0.0|
# |1928-01-17| 17.3| 17.3| 17.3| 17.3|     17.3|     0|             0.0578|              0.0|
# |1928-01-18|17.26|17.26|17.26|17.26|    17.26|     0|            -0.2317|              0.0|
# |1928-01-19|17.38|17.38|17.38|17.38|    17.38|     0|             0.6904|              0.0|
# |1928-01-20|17.48|17.48|17.48|17.48|    17.48|     0|             0.5721|              0.0|
# |1928-01-23|17.64|17.64|17.64|17.64|    17.64|     0|              0.907|              0.0|
# |1928-01-24|17.71|17.71|17.71|17.71|    17.71|     0|             0.3953|              0.0|
# |1928-01-25|17.52|17.52|17.52|17.52|    17.52|     0|            -1.0845|              0.0|
# |1928-01-26|17.63|17.63|17.63|17.63|    17.63|     0|             0.6239|              0.0|
# |1928-01-27|17.69|17.69|17.69|17.69|    17.69|     0|             0.3392|              0.0|
# |1928-01-30|17.49|17.49|17.49|17.49|    17.49|     0|            -1.1435|              0.0|
# +----------+-----+-----+-----+-----+---------+------+-------------------+-----------------+
# only showing top 20 rows

# %%
# Preprocessing American congress members investment dataset

# It seems that even with the inferSchema some columns(Date, Amount) have the wrong type
# In the following code we are changing these columns types
authorities_df = authorities_df.withColumn("Amount", authorities_df["Amount"].cast("integer"))
authorities_df = authorities_df.withColumn("Date", functions.to_date(authorities_df["Date"], 'M/d/yyyy'))

authorities_df.printSchema()
authorities_df.show()
# Out:
# root
#  |-- Index: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Owner: string (nullable = true)
#  |-- Ticker: string (nullable = true)
#  |-- Asset_Name: string (nullable = true)
#  |-- Asset_Type: string (nullable = true)
#  |-- Transaction_Type: string (nullable = true)
#  |-- Amount: integer (nullable = true)
#  |-- Comment: string (nullable = true)
#
# +-----+--------------------+----------+------+------+--------------------+----------+----------------+------+--------------------+
# |Index|                Name|      Date| Owner|Ticker|          Asset_Name|Asset_Type|Transaction_Type|Amount|             Comment|
# +-----+--------------------+----------+------+------+--------------------+----------+----------------+------+--------------------+
# |    1|  Sheldon Whitehouse|2014-11-25|  Self|     M| Macy's, Inc. (NYSE)|     Stock|        Purchase|  1001|                  --|
# |    2|  Sheldon Whitehouse|2014-12-18|  Self|  BEAV|B/E Aerospace Inc...|     Stock|     Sale (Full)| 15001|                  --|
# |    3|  Sheldon Whitehouse|2014-12-18|  Self|  KORS|Michael Kors Hold...|     Stock|  Sale (Partial)|  1001|                  --|
# |    4|  Sheldon Whitehouse|2014-12-18|  Self|     T|   AT&T, Inc. (NYSE)|     Stock|        Purchase|  1001|                  --|
# |    5|  Sheldon Whitehouse|2014-12-18|  Self|  KEYS|Keysight Technolo...|     Stock|     Sale (Full)|  1001|Agilent Tech comm...|
# |    6|  Sheldon Whitehouse|2014-12-18|  Self|  ABBV|  AbbVie Inc. (NYSE)|     Stock|        Purchase|  1001|                  --|
# |    7|  Sheldon Whitehouse|2014-12-18|  Self|  SSYS|Stratasys Ltd. (N...|     Stock|     Sale (Full)|  1001|                  --|
# |    8|  Sheldon Whitehouse|2014-12-18|  Self|   HYH|Halyard Health, I...|     Stock|     Sale (Full)|  1001|KMB completed a s...|
# |    9|  Sheldon Whitehouse|2014-12-18|  Self|  AMGN| Amgen Inc. (NASDAQ)|     Stock|        Purchase| 15001|                  --|
# |   10|  Sheldon Whitehouse|2014-11-25| Joint|   PRU|Prudential Financ...|     Stock|        Purchase|  1001|                  --|
# |   11|  Sheldon Whitehouse|2014-11-25| Joint|  PCAR|PACCAR Inc. (NASDAQ)|     Stock|        Purchase|  1001|                  --|
# |   12|  Sheldon Whitehouse|2014-12-18| Joint|  CMRE|Costamare Inc. (N...|     Stock|        Purchase|  1001|                  --|
# |   13|  Sheldon Whitehouse|2014-11-25| Child|   IBM|International Bus...|     Stock|  Sale (Partial)|  1001|                  --|
# |   14|  Sheldon Whitehouse|2014-11-25| Child|  PCAR|PACCAR Inc. (NASDAQ)|     Stock|        Purchase|  1001|                  --|
# |   15|  Sheldon Whitehouse|2014-12-18| Child|  KORS|Michael Kors Hold...|     Stock|  Sale (Partial)|  1001|                  --|
# |   16|  Sheldon Whitehouse|2014-12-18| Child|     T|   AT&T, Inc. (NYSE)|     Stock|        Purchase|  1001|                  --|
# |   17|  Sheldon Whitehouse|2014-12-18| Child|  ORCL|Oracle Corporatio...|     Stock|        Purchase|  1001|                  --|
# |   18|  Sheldon Whitehouse|2014-12-18|Spouse|   TJX|The TJX Companies...|     Stock|        Purchase|  1001|                  --|
# | 6295| A. Mitchell McCo...|2019-03-05|Spouse|   WFC|Wells Fargo & Com...|     Stock|        Purchase|  1001|Dividend Reinvest...|
# | 6296| A. Mitchell McCo...|2017-09-07|Spouse|   WFC|Wells Fargo & Com...|     Stock|        Purchase|  1001|Dividend Reinvest...|
# +-----+--------------------+----------+------+------+--------------------+----------+----------------+------+--------------------+
# only showing top 20 rows

# %%
# Transforming bitcoin historical dataset timestamp column (date) into date type
# Note that the current timestamps are note in the real range of years
# We need to remove the 3 last numbers digit to retrieve the real time stamp
# example : 1609430400000 to 1609430400
# btc_df = btc_df.withColumn("date", functions.floor(functions.col("date") / 1000))

# Transforming the string type into date type
#btc_df = btc_df.withColumn("Date", functions.from_unixtime(btc_df["Date"], 'yyyy-MM-dd'))
btc_df = btc_df.withColumn("Date", functions.to_date(btc_df["Date"], 'yyyy-MM-dd'))


# Showing bitcoin historical data
btc_df.printSchema()
btc_df.show()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Adj Close: double (nullable = true)
#  |-- Volume: long (nullable = true)
#
# +----------+----------+----------+----------+----------+----------+--------+
# |      Date|      Open|      High|       Low|     Close| Adj Close|  Volume|
# +----------+----------+----------+----------+----------+----------+--------+
# |2014-09-17|465.864014|468.174011|452.421997|457.334015|457.334015|21056800|
# |2014-09-18|456.859985|456.859985|413.104004|424.440002|424.440002|34483200|
# |2014-09-19|424.102997|427.834991|384.532013| 394.79599| 394.79599|37919700|
# |2014-09-20|394.673004| 423.29599|389.882996|408.903992|408.903992|36863600|
# |2014-09-21|408.084991|412.425995|   393.181|398.821014|398.821014|26580100|
# |2014-09-22|399.100006|406.915985|397.130005|402.152008|402.152008|24127600|
# |2014-09-23| 402.09201|441.557007|396.196991|435.790985|435.790985|45099500|
# |2014-09-24|435.751007|   436.112|421.131989|423.204987|423.204987|30627700|
# |2014-09-25|423.156006|423.519989|409.467987|411.574005|411.574005|26814400|
# |2014-09-26|411.428986|414.937988|400.009003|404.424988|404.424988|21460800|
# |2014-09-27|   403.556|406.622986|397.372009|399.519989|399.519989|15029300|
# |2014-09-28|399.471008|401.016998|374.332001|   377.181|   377.181|23613300|
# |2014-09-29|376.928009|385.210999| 372.23999| 375.46701| 375.46701|32497700|
# |2014-09-30|376.088013| 390.97699|373.442993|   386.944|   386.944|34707300|
# |2014-10-01|387.427002|391.378998|380.779999| 383.61499| 383.61499|26229400|
# |2014-10-02|383.988007|385.497009|372.946014|375.071991|375.071991|21777700|
# |2014-10-03|   375.181|377.695007|357.859009|359.511993|359.511993|30901200|
# |2014-10-04|359.891998|   364.487|325.885986|328.865997|328.865997|47236500|
# |2014-10-05|328.915985|341.800995| 289.29599| 320.51001| 320.51001|83308096|
# |2014-10-06|320.389008|345.134003|302.559998| 330.07901| 330.07901|79011800|
# +----------+----------+----------+----------+----------+----------+--------+
# only showing top 20 rows

# %%
# Displaying datasets description

print("********* S&P 500 **********")
spx_df.describe().show()
print("********* Bitcoin **********")
btc_df.describe().show()
print("********* Authorities **********")
authorities_df.describe().show()
# Out:
# ********* S&P 500 **********
# +-------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+-------------------+--------------------+
# |summary|             Open|             High|              Low|            Close|        Adj Close|              Volume|% Gain/Loss (Close)|   % Price Variation|
# +-------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+-------------------+--------------------+
# |  count|            19685|            19685|            19685|            19685|            19685|               19685|              19685|               19685|
# |   mean|619.1470769621535|622.7524820929647|615.3170393700764|619.2868717297447|619.2868717297447| 9.580700756921514E8|0.01935314198628395|0.010685394970789436|
# | stddev|839.9325291644789|844.2528031660208|835.2678036374305|840.1093805849857|840.1093805849857|1.6151891503754709E9| 1.3294124979586408|0.009624452604807784|
# |    min|              4.4|              4.4|              4.4|              4.4|              4.4|                   0|           -34.2227|                 0.0|
# |    max|          4535.38|          4545.85|          4524.66|          4536.95|          4536.95|         11456230000|            22.2621|               0.257|
# +-------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+-------------------+--------------------+
#
# ********* Bitcoin **********
# +-------+------------------+------------------+------------------+------------------+------------------+--------------------+
# |summary|              Open|              High|               Low|             Close|         Adj Close|              Volume|
# +-------+------------------+------------------+------------------+------------------+------------------+--------------------+
# |  count|              2747|              2747|              2747|              2747|              2747|                2747|
# |   mean| 11668.60027202253|11981.034948757877|11325.596906695631|11682.892098396766|11682.892098396766|1.484703972535493...|
# | stddev|16323.683852968808| 16759.56865743851|15825.584506625517|16330.191581967387|16330.191581967387|1.994819029797687E10|
# |    min|        176.897003|        211.731003|        171.509995|        178.102997|        178.102997|             5914570|
# |    max|      67549.734375|         68789.625|        66382.0625|      67566.828125|      67566.828125|        350967941479|
# +-------+------------------+------------------+------------------+------------------+------------------+--------------------+
#
# ********* Authorities **********
# +-------+----------------+--------------------+------+------+--------------------+------------+----------------+------------------+--------------------+
# |summary|           Index|                Name| Owner|Ticker|          Asset_Name|  Asset_Type|Transaction_Type|            Amount|             Comment|
# +-------+----------------+--------------------+------+------+--------------------+------------+----------------+------------------+--------------------+
# |  count|           15666|               15666| 15666| 15666|               15666|       14250|           15666|             15665|               15666|
# |   mean|          7833.5|                null|  null|  null|                null|        null|            null|19806.936801787426|               555.0|
# | stddev|4522.52899382634|                null|  null|  null|                null|        null|            null|139100.97991337965|                 0.0|
# |    min|               1| A. Mitchell McCo...| Child|    --|11.15% due 9/30/1...|        Bond|        Exchange|              1001|"""CALLED"" REDEM...|
# |    max|           15666| William F Hagert...|Spouse|   ZTS|                znga|Stock Option|  Sale (Partial)|           5000001|          ugma--lily|
# +-------+----------------+--------------------+------+------+--------------------+------------+----------------+------------------+--------------------+

# %%
# Displaying the range of date in each dataset
print("********* S&P 500 **********")
spx_df.select(functions.min("Date"), functions.max("Date")).show()
print("********* Bitcoin **********")
btc_df.select(functions.min("date"), functions.max("date")).show()
print("********* Authorities **********")
authorities_df.select(functions.min("date"), functions.max("date")).show()
# Out:
# ********* S&P 500 **********
# +----------+----------+
# | min(Date)| max(Date)|
# +----------+----------+
# |1927-12-30|2021-09-17|
# +----------+----------+
#
# ********* Bitcoin **********
# +----------+----------+
# | min(date)| max(date)|
# +----------+----------+
# |2014-09-17|2022-03-25|
# +----------+----------+
#
# ********* Authorities **********
# +----------+----------+
# | min(date)| max(date)|
# +----------+----------+
# |2011-11-29|2021-07-30|
# +----------+----------+

# %%
# Transaction made on cryptocurrency
Crypto_Transaction=authorities_df.where(authorities_df.Asset_Type == "Cryptocurrency")
print("percentage of transaction :",((Crypto_Transaction.count()*100)/authorities_df.count()))
Crypto_Transaction.show()
# Out:
# percentage of transaction : 0.012766500702157539
# +-----+-----------------+----------+-----+------+--------------------+--------------+----------------+------+-------+
# |Index|             Name|      Date|Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|Amount|Comment|
# +-----+-----------------+----------+-----+------+--------------------+--------------+----------------+------+-------+
# |  865| Patrick J Toomey|2021-06-15| Self|  GBTC|Grayscale Bitcoin...|Cryptocurrency|        Purchase|  1001|     --|
# |  866| Patrick J Toomey|2021-06-14| Self|  ETHE|Grayscale Ethereu...|Cryptocurrency|        Purchase|  1001|     --|
# +-----+-----------------+----------+-----+------+--------------------+--------------+----------------+------+-------+

# %% [markdown]
# > Only 2 Crypto transaction has bee declared bt authorities. This information is critical as we don't have enough data to analyse authorities transaction on the crypto market

# %% [markdown]
# ### 4.2. Filtering transactions on S&P500 Companies

# %%
# S&P companies tickers

import urllib # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents

# Scrapping S&P companies on wikipedia
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, 'lxml')
all_tables=soup.find_all("table")
companies_table=soup.find('table',{'class':"wikitable"})

symbol=[]
for row in companies_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==8:
        symbol.append(cells[0].find(text=True))
# Out:
# <ipython-input-35-8a32b3e12e31>:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   symbol.append(cells[0].find(text=True))

# %%
# Filter all transaction for S&P 500 companies
authorities_df_SP=authorities_df.filter(authorities_df.Ticker.isin(symbol))

# %%
authorities_df_SP.describe().show()
# Out:
# +-------+------------------+--------------------+------+------+--------------------+--------------+----------------+------------------+--------------------+
# |summary|             Index|                Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|            Amount|             Comment|
# +-------+------------------+--------------------+------+------+--------------------+--------------+----------------+------------------+--------------------+
# |  count|              6959|                6959|  6959|  6959|                6959|          6507|            6959|              6959|                6959|
# |   mean|7451.3533553671505|                null|  null|  null|                null|          null|            null|14141.250035924702|               555.0|
# | stddev|  4383.66894280683|                null|  null|  null|                null|          null|            null| 139053.9490099571|                 0.0|
# |    min|                 4| A. Mitchell McCo...| Child|     A|21st Century Fox CMN|Corporate Bond|        Exchange|              1001|"Corrected the ow...|
# |    max|             15587| William F Hagert...|Spouse|   ZTS|                 tjx|  Stock Option|  Sale (Partial)|           5000001|          ugma--lily|
# +-------+------------------+--------------------+------+------+--------------------+--------------+----------------+------------------+--------------------+

# %% [markdown]
# > Half of transactions have been made on S&P 500 companies (7060 Transaction)

# %%
authorities_df_SP.select("Ticker").distinct().show(200)
# Out:
# +------+
# |Ticker|
# +------+
# |   GIS|
# |   LEN|
# |     K|
# |   RTX|
# |    RF|
# |   MMM|
# |   KKR|
# |   PPG|
# |   AXP|
# |   WEC|
# |    CI|
# |   IRM|
# |    PM|
# |   SNA|
# |   PFG|
# |    EA|
# |   OXY|
# |   BLK|
# |   WAB|
# |  CRWD|
# |   DUK|
# |   STE|
# |   HAS|
# |   MTD|
# |  TROW|
# |   JBL|
# |   KIM|
# |   PRU|
# |   DGX|
# |  AAPL|
# |   CLX|
# |   ALL|
# |  CSCO|
# |   CZR|
# |   TSN|
# |   BMY|
# |   XOM|
# |   CMG|
# |   FRT|
# |  MCHP|
# |   ADI|
# |     F|
# |   FTV|
# |   SYY|
# |  JNPR|
# |   TEL|
# |   ROP|
# |  CHRW|
# |   EQR|
# |   SPG|
# |   ZBH|
# |   NUE|
# |  GILD|
# |  HOLX|
# |  AMGN|
# |  QCOM|
# |   OKE|
# |   IEX|
# |   PNC|
# |   JPM|
# |  MNST|
# |  PANW|
# |   EOG|
# |   WFC|
# |   SYK|
# |   HSY|
# |  GDDY|
# |   DIS|
# |   HAL|
# |   MPC|
# |   TDY|
# |   DHR|
# |   BSX|
# |    BX|
# |  TSLA|
# |     T|
# |   COP|
# |   ACN|
# |  EXPE|
# |   ARE|
# |   AIG|
# |   MRK|
# |  INTC|
# |    SO|
# |   LYB|
# |   NEE|
# |   EMR|
# |   AFL|
# |    PG|
# |   APH|
# |   DVN|
# |   EXR|
# |  INTU|
# |    WY|
# |  ROST|
# |   MCD|
# |   GPN|
# |   AME|
# |   BDX|
# |  ABBV|
# |  PAYX|
# |   CSX|
# |   IQV|
# |   KMB|
# |   ADP|
# |    VZ|
# |   KMX|
# |   TDG|
# |  ALGN|
# |    CL|
# |   TFC|
# |  VRTX|
# |   ADM|
# |   REG|
# |    DD|
# |   AMT|
# |   UNP|
# |   TXT|
# |   PNR|
# |   LHX|
# |   WMB|
# |   SHW|
# |  DXCM|
# |     L|
# |     V|
# |   TRV|
# |  CARR|
# |   HRL|
# |   AIZ|
# |    LW|
# |   EIX|
# |   MKC|
# |   PGR|
# |   PFE|
# |   FCX|
# |   RMD|
# |  PCAR|
# |  GOOG|
# |   DVA|
# |    DE|
# |   AES|
# |  NFLX|
# |   TAP|
# |   PKG|
# |  COST|
# |  FANG|
# |    IR|
# |    MO|
# |   UNH|
# |     O|
# |     D|
# |    ES|
# |  TECH|
# |   IBM|
# |   OMC|
# |   BXP|
# |   COF|
# |   BWA|
# |   LKQ|
# |   JNJ|
# |   IVZ|
# |  FOXA|
# |   CVX|
# |   ALB|
# |   CAG|
# |  TSCO|
# |   LYV|
# |  ISRG|
# |   PLD|
# |     C|
# |    KR|
# |  APTV|
# |   NSC|
# |   MMC|
# |   EXC|
# |   VMC|
# |   GLW|
# |    LH|
# |    MS|
# |   CMI|
# |   TGT|
# |   TJX|
# |  KLAC|
# |   SWK|
# |    GM|
# |   AEP|
# |   DTE|
# |   AWK|
# |    BK|
# |   DFS|
# |   FOX|
# |   NOC|
# |   FIS|
# |   ROK|
# |   ESS|
# |   LIN|
# |  TMUS|
# |   KMI|
# |   HPE|
# |     A|
# +------+
# only showing top 200 rows

# %% [markdown]
# ### 4.3. Merging Authorities transaction and S&P 500 stock price data into training Data

# %%
authorities_df_SP.describe().show()
# Out:
# +-------+------------------+--------------------+------+------+--------------------+--------------+----------------+------------------+--------------------+
# |summary|             Index|                Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|            Amount|             Comment|
# +-------+------------------+--------------------+------+------+--------------------+--------------+----------------+------------------+--------------------+
# |  count|              6959|                6959|  6959|  6959|                6959|          6507|            6959|              6959|                6959|
# |   mean|7451.3533553671505|                null|  null|  null|                null|          null|            null|14141.250035924702|               555.0|
# | stddev|  4383.66894280683|                null|  null|  null|                null|          null|            null| 139053.9490099571|                 0.0|
# |    min|                 4| A. Mitchell McCo...| Child|     A|21st Century Fox CMN|Corporate Bond|        Exchange|              1001|"Corrected the ow...|
# |    max|             15587| William F Hagert...|Spouse|   ZTS|                 tjx|  Stock Option|  Sale (Partial)|           5000001|          ugma--lily|
# +-------+------------------+--------------------+------+------+--------------------+--------------+----------------+------------------+--------------------+

# %%
authorities_df_SP.printSchema()
# Out:
# root
#  |-- Index: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Owner: string (nullable = true)
#  |-- Ticker: string (nullable = true)
#  |-- Asset_Name: string (nullable = true)
#  |-- Asset_Type: string (nullable = true)
#  |-- Transaction_Type: string (nullable = true)
#  |-- Amount: integer (nullable = true)
#  |-- Comment: string (nullable = true)

# %%
from pyspark.sql.functions import col, date_add, date_sub
from pyspark.sql.types import DateType

def compute_price(df, date)->float:
    """
    This function compute an approximation of the stock price for a given date,
    based on the price of the next and the privious date in the given dataframe (df)
    parameters:
      - df : pyspark dataframe
      - date : date in datetype
    return:
      - price in float
    """
    # Calculate target price as average of prices for previous and next days
    prev_date = df.filter(col("Date") < date).orderBy(col("Date").desc()).select("Date").first()
    next_date = df.filter(col("Date") > date).orderBy(col("Date")).select("Date").first()
    prev_price = df.filter(col("Date") == prev_date[0]).select("Open").first()[0]
    next_price = df.filter(col("Date") == next_date[0]).select("Open").first()[0]
    three_days_later_price = (prev_price + next_price) / 2
    return three_days_later_price


def get_stock_prices_before(df, target_date)->list:
    """
    - This function take a dataframe and a given date as parameters
    - It return the prices of the s&p 3 days, 3 weeks 3 month, 3 quaters and 3 years before (as a list)
    parameters :
      - df : pyspark dataframe
      - target_date : date in datetype
    return:
      - List of prices values
    """

    # Get stock price for target_date
    try:
        target_price = df.filter(col("Date") == target_date).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        target_price = compute_price(df, target_date)

    # Get stock price for 3 days before
    three_days_before = target_date - datetime.timedelta(days=3)
    try:
        three_days_before_price = df.filter(col("Date") == three_days_before).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        three_days_before_price = compute_price(df, three_days_before)

    # Get stock price for 3 weeks before
    three_weeks_before = target_date - datetime.timedelta(days=21)
    try:
        three_weeks_before_price = df.filter(col("Date") == three_weeks_before).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        three_weeks_before_price = compute_price(df, three_weeks_before)

    # Get stock price for 3 months before
    three_months_before = target_date - datetime.timedelta(days=90)
    try:
        three_months_before_price = df.filter(col("Date") == three_months_before).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        three_months_before_price = compute_price(df, three_months_before)


    # Get stock price for 3 quarters before (9 months)
    three_quarters_before = target_date - datetime.timedelta(days=270)
    try:
        three_quarters_before_price = df.filter(col("Date") == three_quarters_before).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        three_quarters_before_price = compute_price(df, three_quarters_before)


    # Get stock price for 3 years before
    three_years_before = target_date - datetime.timedelta(days=1095)
    try:
        three_years_before_price = df.filter(col("Date") == three_years_before).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        three_years_before_price = compute_price(df, three_years_before)

    data = [target_date,target_price,three_days_before_price,three_weeks_before_price,
            three_months_before_price,three_quarters_before_price,
            three_years_before_price]
    return data


def get_stock_prices_after(df, target_date)->list:
    """
    - This function take a dataframe and a given date as parameters
    - It return the prices of the s&p after 3 days, 3 weeks 3 month, 3 quaters and 3 years (as a list)
    parameters :
      - df : pyspark dataframe
      - target_date : date in datetype
    return:
      - List of prices values
    """


    # Get stock price for 3 days later
    three_days_later = target_date + datetime.timedelta(days=3)
    try:
          three_days_later_price = df.filter(col("Date") == three_days_later).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
          three_days_later_price = compute_price(df, three_days_later)


    # Get stock price for 3 weeks later
    three_weeks_later = target_date + datetime.timedelta(days=21)
    try:
          three_weeks_later_price = df.filter(col("Date") == three_weeks_later).select("Open").first()[0]
    except:
          # we compute an approximation of thr price in case we don't have value in the data
          three_weeks_later_price = compute_price(df, three_weeks_later)


    # Get stock price for 3 months later
    three_months_later = target_date + datetime.timedelta(days=90)
    try:
        three_months_later_price = df.filter(col("Date") == three_months_later).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        three_months_later_price = compute_price(df, three_months_later)


    # Get stock price for 3 quarters later (9 months)
    three_quarters_later = target_date + datetime.timedelta(days=270)
    try:
        three_quarters_later_price = df.filter(col("Date") == three_quarters_later).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        three_quarters_later_price = compute_price(df, three_quarters_later)


    # Get stock price for 3 years later
    three_years_later = target_date + datetime.timedelta(days=1095)
    try:
        three_years_later_price = df.filter(col("Date") == three_years_later).select("Open").first()[0]
    except:
        # we compute an approximation of thr price in case we don't have value in the data
        three_years_later_price = compute_price(df, three_years_later)


    data = [three_days_later_price,
            three_weeks_later_price,three_months_later_price,
            three_quarters_later_price,three_years_later_price]
    return data



def stock_price_fluct(transaction_date,s_p_price)->list:
    """
    - This function take dates of each transactions, and return the fluctuation of S&P prices
        * 3 days, 3 weeks, 3 months, 3 quater and 3 years before and after the trasaction
    - The returning list is a list of list. each inside list contains the fluctuation of price for a given transaction date
    Parameters:
      - transaction_date : is a dataframe of ( with one signle column, which is Date column)
      - s_p_price: is a dataframe of stock price
    Return :
      - List of prices lists
    """
    stock_price=[]
    m=1

    # Boundering of date
    max_date=spx_df.select(functions.max("Date")).collect()[0][0]
    for date in transaction_date.collect()[:7061]:
        if date[0] < max_date - datetime.timedelta(days=1095):
            print(m," ** ",date[0])
            data_1 = get_stock_prices_before(s_p_price, date[0])
            data_2 = get_stock_prices_after(s_p_price, date[0])
            value = data_1 + data_2
            stock_price.append(value)
            m+=1
    return stock_price

# %%
# This step take time - if you don't have time you can run the next cell instead of this one
#stock_price = stock_price_fluct(authorities_df_SP.select("Date"),spx_df.select("Date","Open"))

# %%
# As we already collect the stock price fuctuation for different time, you can directly import the variable via pickle
# Instead of running the function again
import pickle
# Load the variable from the file
with open("/content/numerical_data.pkl", "rb") as f:
    loaded_variable = pickle.load(f)

# %%
len(loaded_variable)
# Out:
# 5137

# %%
# Create new pyspark data frame to store the stock price fluctuation

from pyspark.sql.types import DoubleType, StructType, DateType, StructField, IntegerType, StringType

schema = StructType([
    StructField("Date", DateType(), True),
    StructField("current_day_price", DoubleType(), True),
    StructField("3_days_before", DoubleType(), True),
    StructField("3_weeks_before", DoubleType(), True),
    StructField("3_months_before", DoubleType(), True),
    StructField("3_quarters_before", DoubleType(), True),
    StructField("3_years_before", DoubleType(), True),
    StructField("3_days_after", DoubleType(), True),
    StructField("3_weeks_after", DoubleType(), True),
    StructField("3_months_after", DoubleType(), True),
    StructField("3_quarters_after", DoubleType(), True),
    StructField("3_years_after", DoubleType(), True),
])


df = spark.createDataFrame(loaded_variable, schema)
df = df.dropDuplicates(["Date"])

# %%
df.describe().show()
# Out:
# +-------+------------------+------------------+------------------+-----------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+
# |summary| current_day_price|     3_days_before|    3_weeks_before|  3_months_before| 3_quarters_before|   3_years_before|      3_days_after|     3_weeks_after|    3_months_after| 3_quarters_after|     3_years_after|
# +-------+------------------+------------------+------------------+-----------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+
# |  count|               777|               777|               777|              777|               777|              777|               777|               777|               777|              777|               777|
# |   mean|2226.4555727155735|  2225.41030888031|2212.4519498069467|2176.125405405406|2065.2707335907303|1642.441891891893|2229.2751158301153| 2241.814575289574|2278.9748455598465|2370.484079794077|3044.3749678249674|
# | stddev|316.35772827461057|315.23909535653434|309.75282266395465|293.7139706841691| 267.9769807152762|312.0112256912718| 316.7892100455367|322.79625096350657|321.86234315207577|326.1268299467318| 593.1373538413122|
# |    min|           1362.33|           1330.12|           1325.72|          1329.19|           1144.11|          907.755|           1373.72|           1362.34|           1427.84|          1566.02|1891.8400000000001|
# |    max|           2903.83|           2906.38|           2884.69|          2847.48|           2683.02|          2130.36|           2919.73|           2926.29|           2931.69|          2940.58|            4533.9|
# +-------+------------------+------------------+------------------+-----------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+

# %%
max_date_spx = spx_df.select(functions.max("Date")).collect()[0][0]
max_date = max_date_spx  - datetime.timedelta(days=1095)

# %%
# Joining authorities transaction dataframe and price fluctuation dataframe
df_joined = authorities_df_SP.filter(authorities_df_SP.Date < max_date).join(df, on="Date", how="inner")

# %%
df_joined.describe().show()
# Out:
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |summary|            Index|                Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|           Amount|             Comment| current_day_price|    3_days_before|    3_weeks_before|   3_months_before| 3_quarters_before|    3_years_before|      3_days_after|     3_weeks_after|    3_months_after|  3_quarters_after|     3_years_after|
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |  count|             5025|                5025|  5025|  5025|                5025|          4578|            5025|             5025|                5025|              5025|             5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|
# |   mean| 7937.77592039801|                null|  null|  null|                null|          null|            null|7236.223880597015|               555.0|2127.7732189054664|2125.179716417913|2109.1696368159396|2077.2214427860845|1947.2029044775702|1560.8762855721668| 2130.886540298543| 2142.772610945247|2187.4744079602215|2277.9351333332866| 2854.691912437694|
# | stddev|4387.219941696174|                null|  null|  null|                null|          null|            null|18382.03678995337|                 0.0|320.69647868355196| 320.932261079029| 321.0736242400423| 336.0416642015048| 305.5774009410719| 313.8790068831807|318.47079756960966|326.14640046316686| 328.7684766160583| 311.6162532312757| 612.0715405021374|
# |    min|                4| A. Mitchell McCo...| Child|     A|21st Century Fox CMN|Corporate Bond|        Exchange|             1001|"Corrected the ow...|           1362.33|          1330.12|           1325.72|           1329.19|           1144.11|           907.755|           1373.72|           1362.34|           1427.84|           1566.02|1891.8400000000001|
# |    max|            15585|     William Cassidy|Spouse|   ZTS|                 tjx|         Stock|  Sale (Partial)|           250001|          ugma--lily|           2903.83|          2906.38|           2884.69|           2847.48|           2683.02|           2130.36|           2919.73|           2926.29|           2931.69|           2940.58|            4533.9|
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+

# %%
# Filling null columns
df_joined = df_joined.fillna({"Asset_Type": "Stock"})

# %%
df_joined.printSchema()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- Index: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Owner: string (nullable = true)
#  |-- Ticker: string (nullable = true)
#  |-- Asset_Name: string (nullable = true)
#  |-- Asset_Type: string (nullable = false)
#  |-- Transaction_Type: string (nullable = true)
#  |-- Amount: integer (nullable = true)
#  |-- Comment: string (nullable = true)
#  |-- current_day_price: double (nullable = true)
#  |-- 3_days_before: double (nullable = true)
#  |-- 3_weeks_before: double (nullable = true)
#  |-- 3_months_before: double (nullable = true)
#  |-- 3_quarters_before: double (nullable = true)
#  |-- 3_years_before: double (nullable = true)
#  |-- 3_days_after: double (nullable = true)
#  |-- 3_weeks_after: double (nullable = true)
#  |-- 3_months_after: double (nullable = true)
#  |-- 3_quarters_after: double (nullable = true)
#  |-- 3_years_after: double (nullable = true)

# %% [markdown]
# ### 4.4. Processing training data

# %%
training = df_joined

# %%
training.show()
# Out:
# +----------+-----+-------------------+------+------+--------------------+----------+----------------+------+-------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# |      Date|Index|               Name| Owner|Ticker|          Asset_Name|Asset_Type|Transaction_Type|Amount|Comment|current_day_price|3_days_before|3_weeks_before|   3_months_before|3_quarters_before|3_years_before|3_days_after|3_weeks_after|    3_months_after|3_quarters_after|3_years_after|
# +----------+-----+-------------------+------+------+--------------------+----------+----------------+------+-------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# |2018-08-10| 3022|  David A Perdue Jr| Joint|   CZR|Caesars Entertain...|     Stock|        Purchase|  1001|     --|           2838.9|      2855.92|       2804.55|          2730.585|          2576.53|       2102.66|     2835.46|      2898.37|           2806.38|         2913.03|      4437.77|
# |2018-08-10| 3021|  David A Perdue Jr| Joint|   MOS|  The Mosaic Company|     Stock|  Sale (Partial)|  1001|     --|           2838.9|      2855.92|       2804.55|          2730.585|          2576.53|       2102.66|     2835.46|      2898.37|           2806.38|         2913.03|      4437.77|
# |2016-03-01|12797|       Thad Cochran|  Self|   MET|       MetLife, Inc.|     Stock|        Purchase| 15001|     --|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |2016-03-01|  273| Sheldon Whitehouse| Child|     V|           Visa Inc.|     Stock|  Sale (Partial)|  1001|     --|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |2016-03-01|  272| Sheldon Whitehouse| Child|   CVS|CVS Health Corpor...|     Stock|  Sale (Partial)|  1001|     --|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |2016-03-01| 3659|  David A Perdue Jr| Joint|    GE|Cabela's Incorpor...|     Stock|  Sale (Partial)|  1001|     --|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |2017-09-11| 5393|  David A Perdue Jr| Joint|   MRK|   Merck & Co., Inc.|     Stock|        Purchase|  1001|     --|          2474.52|      2462.25|        2425.5|           2434.15|          2253.77|       1996.74|     2494.56|       2521.2|            2649.2|         2765.84|      3412.56|
# |2017-08-11| 2027|        Pat Roberts|Spouse|    BA|BA-The Boeing Com...|     Stock|        Purchase|  1001|    sep|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# |2017-08-11| 5481|  David A Perdue Jr| Joint|    RF|Regions Financial...|     Stock|        Purchase|  1001|     --|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# |2017-08-11| 5480|  David A Perdue Jr| Joint|   WMT|Wal-Mart Stores, ...|     Stock|  Sale (Partial)| 15001|     --|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# |2015-03-09| 1845|        Pat Roberts|Spouse|  AMZN|Amazon.com Inc. (...|     Stock|     Sale (Full)| 15001|      R|          2072.25|      2100.91|      2092.625|           2056.55|          1943.35|       1365.97|      2041.1|      2064.11|          2093.715|         2051.24|      2732.75|
# |2015-03-06| 1844|        Pat Roberts|Spouse|  SBUX|Starbucks Corpora...|     Stock|        Purchase|  1001|      R|          2100.91|      2115.76|       2088.78|2073.8100000000004|          1948.97|       1363.63|     2072.25|      2055.78|           2112.35|         2082.93|      2681.06|
# |2015-03-06| 1843|        Pat Roberts|Spouse|  COST|Costco Wholesale ...|     Stock|        Purchase|  1001|      R|          2100.91|      2115.76|       2088.78|2073.8100000000004|          1948.97|       1363.63|     2072.25|      2055.78|           2112.35|         2082.93|      2681.06|
# |2018-06-06|  556| Sheldon Whitehouse|Spouse|   WMT|        Walmart Inc.|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  555| Sheldon Whitehouse|Spouse|  PYPL|PayPal Holdings, ...|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  554| Sheldon Whitehouse|Spouse|  LRCX|Lam Research Corp...|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  553| Sheldon Whitehouse|Spouse|    GS|The Goldman Sachs...|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  552| Sheldon Whitehouse|Spouse|   DAL|Delta Air Lines, ...|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  551| Sheldon Whitehouse|Spouse|     C|      Citigroup Inc.|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  550| Sheldon Whitehouse|Spouse|    BA|  The Boeing Company|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# +----------+-----+-------------------+------+------+--------------------+----------+----------------+------+-------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# only showing top 20 rows

# %%
training.describe().show()
# Out:
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |summary|            Index|                Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|           Amount|             Comment| current_day_price|    3_days_before|    3_weeks_before|   3_months_before| 3_quarters_before|    3_years_before|      3_days_after|     3_weeks_after|    3_months_after|  3_quarters_after|     3_years_after|
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |  count|             5025|                5025|  5025|  5025|                5025|          5025|            5025|             5025|                5025|              5025|             5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|
# |   mean| 7937.77592039801|                null|  null|  null|                null|          null|            null|7236.223880597015|               555.0|2127.7732189054664|2125.179716417913|2109.1696368159396|2077.2214427860845|1947.2029044775702|1560.8762855721668| 2130.886540298543| 2142.772610945247|2187.4744079602215|2277.9351333332866| 2854.691912437694|
# | stddev|4387.219941696174|                null|  null|  null|                null|          null|            null|18382.03678995337|                 0.0|320.69647868355196| 320.932261079029| 321.0736242400423| 336.0416642015048| 305.5774009410719| 313.8790068831807|318.47079756960966|326.14640046316686| 328.7684766160583| 311.6162532312757| 612.0715405021374|
# |    min|                4| A. Mitchell McCo...| Child|     A|21st Century Fox CMN|Corporate Bond|        Exchange|             1001|"Corrected the ow...|           1362.33|          1330.12|           1325.72|           1329.19|           1144.11|           907.755|           1373.72|           1362.34|           1427.84|           1566.02|1891.8400000000001|
# |    max|            15585|     William Cassidy|Spouse|   ZTS|                 tjx|         Stock|  Sale (Partial)|           250001|          ugma--lily|           2903.83|          2906.38|           2884.69|           2847.48|           2683.02|           2130.36|           2919.73|           2926.29|           2931.69|           2940.58|            4533.9|
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+

# %%
# selected columns for analysis part
selected_colunmn = ["index","Transaction_Type","Amount","1st_week_profit","2nd_week_profit"]

cat_column = ["Name","Owner","Ticker","Asset_Name","Asset_Type","Transaction_Type"] # categorical columns

#training= training.select(selected_colunmn)

# %%
training.describe().show()
# Out:
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |summary|            Index|                Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|           Amount|             Comment| current_day_price|    3_days_before|    3_weeks_before|   3_months_before| 3_quarters_before|    3_years_before|      3_days_after|     3_weeks_after|    3_months_after|  3_quarters_after|     3_years_after|
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |  count|             5025|                5025|  5025|  5025|                5025|          5025|            5025|             5025|                5025|              5025|             5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|              5025|
# |   mean| 7937.77592039801|                null|  null|  null|                null|          null|            null|7236.223880597015|               555.0|2127.7732189054664|2125.179716417913|2109.1696368159396|2077.2214427860845|1947.2029044775702|1560.8762855721668| 2130.886540298543| 2142.772610945247|2187.4744079602215|2277.9351333332866| 2854.691912437694|
# | stddev|4387.219941696174|                null|  null|  null|                null|          null|            null|18382.03678995337|                 0.0|320.69647868355196| 320.932261079029| 321.0736242400423| 336.0416642015048| 305.5774009410719| 313.8790068831807|318.47079756960966|326.14640046316686| 328.7684766160583| 311.6162532312757| 612.0715405021374|
# |    min|                4| A. Mitchell McCo...| Child|     A|21st Century Fox CMN|Corporate Bond|        Exchange|             1001|"Corrected the ow...|           1362.33|          1330.12|           1325.72|           1329.19|           1144.11|           907.755|           1373.72|           1362.34|           1427.84|           1566.02|1891.8400000000001|
# |    max|            15585|     William Cassidy|Spouse|   ZTS|                 tjx|         Stock|  Sale (Partial)|           250001|          ugma--lily|           2903.83|          2906.38|           2884.69|           2847.48|           2683.02|           2130.36|           2919.73|           2926.29|           2931.69|           2940.58|            4533.9|
# +-------+-----------------+--------------------+------+------+--------------------+--------------+----------------+-----------------+--------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+

# %%
from pyspark.ml.feature import StringIndexer

# Categorical columns indexation
df_indexed=training
i=0
for col in cat_column:
  indexer=StringIndexer(inputCol=col, outputCol=col+"_index")
  df_indexed = indexer.fit(df_indexed).transform(df_indexed)
  i+=1


df_indexed = df_indexed.select(
    "index","Name_index","Owner_index","Ticker_index","Asset_Name_index","Asset_Type_index","Transaction_Type_index",
    "current_day_price","3_days_before","3_weeks_before","3_months_before","3_quarters_before","3_years_before",
    "3_days_after","3_weeks_after","3_months_after","3_quarters_after","3_years_after"

  )

# %%
df_indexed.show()
# Out:
# +-----+----------+-----------+------------+----------------+----------------+----------------------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# |index|Name_index|Owner_index|Ticker_index|Asset_Name_index|Asset_Type_index|Transaction_Type_index|current_day_price|3_days_before|3_weeks_before|   3_months_before|3_quarters_before|3_years_before|3_days_after|3_weeks_after|    3_months_after|3_quarters_after|3_years_after|
# +-----+----------+-----------+------------+----------------+----------------+----------------------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# | 3022|       1.0|        2.0|        58.0|            31.0|             0.0|                   0.0|           2838.9|      2855.92|       2804.55|          2730.585|          2576.53|       2102.66|     2835.46|      2898.37|           2806.38|         2913.03|      4437.77|
# | 3021|       1.0|        2.0|        31.0|            23.0|             0.0|                   2.0|           2838.9|      2855.92|       2804.55|          2730.585|          2576.53|       2102.66|     2835.46|      2898.37|           2806.38|         2913.03|      4437.77|
# |12797|       4.0|        0.0|        63.0|           183.0|             0.0|                   0.0|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |  273|       3.0|        3.0|        30.0|           190.0|             0.0|                   2.0|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |  272|       3.0|        3.0|        22.0|            58.0|             0.0|                   2.0|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# | 3659|       1.0|        2.0|         2.0|           409.0|             0.0|                   2.0|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# | 5393|       1.0|        2.0|        11.0|            34.0|             0.0|                   0.0|          2474.52|      2462.25|        2425.5|           2434.15|          2253.77|       1996.74|     2494.56|       2521.2|            2649.2|         2765.84|      3412.56|
# | 2027|       5.0|        1.0|        44.0|           543.0|             0.0|                   0.0|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# | 5481|       1.0|        2.0|        60.0|            45.0|             0.0|                   0.0|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# | 5480|       1.0|        2.0|         7.0|            79.0|             0.0|                   2.0|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# | 1845|       5.0|        1.0|        26.0|           193.0|             0.0|                   1.0|          2072.25|      2100.91|      2092.625|           2056.55|          1943.35|       1365.97|      2041.1|      2064.11|          2093.715|         2051.24|      2732.75|
# | 1844|       5.0|        1.0|        37.0|           172.0|             0.0|                   0.0|          2100.91|      2115.76|       2088.78|2073.8100000000004|          1948.97|       1363.63|     2072.25|      2055.78|           2112.35|         2082.93|      2681.06|
# | 1843|       5.0|        1.0|       121.0|           289.0|             0.0|                   0.0|          2100.91|      2115.76|       2088.78|2073.8100000000004|          1948.97|       1363.63|     2072.25|      2055.78|           2112.35|         2082.93|      2681.06|
# |  556|       3.0|        1.0|         7.0|           102.0|             0.0|                   0.0|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |  555|       3.0|        1.0|       205.0|           274.0|             0.0|                   0.0|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |  554|       3.0|        1.0|       232.0|           300.0|             0.0|                   0.0|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |  553|       3.0|        1.0|        55.0|           247.0|             0.0|                   0.0|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |  552|       3.0|        1.0|       191.0|           333.0|             0.0|                   0.0|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |  551|       3.0|        1.0|        27.0|           144.0|             0.0|                   0.0|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |  550|       3.0|        1.0|        44.0|           133.0|             0.0|                   0.0|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# +-----+----------+-----------+------------+----------------+----------------+----------------------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### 4.5. Assembler and standardization

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler
from pyspark.ml.feature import VectorAssembler

# %%
# Assembling
assembler = VectorAssembler(inputCols=df_indexed.columns[1:], outputCol='features', handleInvalid="keep")
data_assembled = assembler.transform(df_indexed).select('index', 'features')

# %%
 # Scaling
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures",
                            withStd=True, withMean=True)
data_scaled = scaler.fit(data_assembled).transform(data_assembled).select("index","scaledFeatures")

# %% [markdown]
# ## 5. Modelling

# %% [markdown]
# There are couple of clustering model that can help us identifying the outliers.
#
# We'll run them on our dataset and compare the results

# %% [markdown]
# ### 5.0. Helper function

# %%
#@markdown import models' libraries

from pyspark.ml.clustering import KMeans
from pyspark.ml.clustering import LDA
from pyspark.ml.clustering import BisectingKMeans
from pyspark.ml.clustering import GaussianMixture

# %%
from pandas.core.indexes.base import zip_longest
from pyspark.ml.linalg import Vectors
import plotly.express as px
from pyspark.ml.feature import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
def threshold(cluster,center)->float:
    """
    parameter:
      - cluster : A dataframe of a single cluster data point
      - center : the center of the cluster
    This function compute a threshold, which is an euclidian distance
    Every data point after this threshold is considered as an outlier
    threshold = (min + max)/2
      * min is equal the minimal distance between on sigle data point and his cluster mean
      * max is the maximal distance between on sigle data point and his cluster mean
    """
    center = Vectors.dense(center)
    min=0.5
    max=0.5
    for raw in cluster.select("scaledFeatures").collect():
        v1 = Vectors.dense(raw[0])
        distance = Vectors.squared_distance(v1, center) ** 0.5
        if distance < min:
          min = distance
        if distance > max:
          max = distance

    threshold = (min + max)/2
    return(threshold)

def outliers_detection(cluster,center,threshold)->list:
    """
     parameter:
      - cluster : A dataframe of a single cluster data point
      - center : the center of the cluster
      - threshold : Threshold of the cluster
    This function return the index of all data after the threshold in term of distance
    return: List of outliers index
    """
    outliers_index=[]
    center = Vectors.dense(center)
    for raw in cluster.select("index","scaledFeatures").collect():
      v1 = Vectors.dense(raw[1])
      distance = Vectors.squared_distance(v1, center) ** 0.5
      if distance > threshold :
        outliers_index.append(raw[0])
    return(outliers_index)

def get_outliers(model,predictions,kindcluster):
  outliers = []
  for row in predictions_kmeans.select("prediction").distinct().toLocalIterator():
    valrow = row['prediction']
    clusterpoints = predictions.filter(predictions.prediction == valrow)
    if kindcluster == 'kmeans':
      center = model.clusterCenters()[valrow]
    elif kindcluster == 'gmm':
      center = [row['mean'].toArray() for row in model_gmm.gaussiansDF.select('mean').collect()][valrow]
    treshold = threshold(clusterpoints,center)
    outliers.extend(outliers_detection(clusterpoints,center,treshold))
  return outliers

# %%
def plotting_2D(predictions):
    """
    This function make a 2D scatter plot of the data, The scatter plot is legended by cluster
    A PCA model help to reduce the dimmenssion before plotting
    """
    # Apply PCA to reduce the dimensionality of the data
    pca = PCA(k=2, inputCol="scaledFeatures", outputCol="pca_features")
    pca_model = pca.fit(predictions)
    pca_data = pca_model.transform(predictions)

    # Convert the PySpark dataframe to a Pandas dataframe for plotting
    pandas_data = pca_data.toPandas()

    # Extract the column of lists into two separate columns
    pandas_data[['x', 'y']] = pd.DataFrame(pandas_data['pca_features'].to_list(), index=pandas_data.index)

    # Plot the scatter plot
    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=pandas_data, x="x", y="y", hue="prediction", palette="Set2", s=100)
    # Remove the top and right spines
    sns.despine(top=True, right=True)
    plt.title("Authorities transactions raw data")

    # Add a grid to the plot
    plt.grid(linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# ### 5.1. kmeans

# %%
kmeans = KMeans(featuresCol="scaledFeatures")
model_kmeans = kmeans.fit(data_scaled)

# %%
predictions_kmeans = model_kmeans.transform(data_scaled)

# %%
plotting_2D(predictions_kmeans)

# %%
kmeans_outliers_indices = get_outliers(model_kmeans,predictions_kmeans,'kmeans')

# %%
kmeans_outliers = data_scaled.filter(col("index").isin(kmeans_outliers_indices))

# %%
results_kmeans = kmeans_outliers.select("index").join(training, on="index", how="inner")
results_kmeans.show()
# Out:
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+-------------+--------------+---------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# |index|      Date|               Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|Amount|             Comment|current_day_price|3_days_before|3_weeks_before|3_months_before| 3_quarters_before|3_years_before|      3_days_after|3_weeks_after|3_months_after|  3_quarters_after|     3_years_after|
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+-------------+--------------+---------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# |  442|2016-08-15| Sheldon Whitehouse| Joint|   CAT|CAT-Caterpillar I...|Corporate Bond|     Sale (Full)| 15001|                  --|          2186.08|      2183.74|       2173.71|        2065.04|            2083.7|       1661.22|            2181.9|      2179.55|      2164.175|           2392.44|            2846.2|
# |  495|2014-11-13| Sheldon Whitehouse| Joint|     T|   AT&T, Inc. (NYSE)|Corporate Bond|  Sale (Partial)| 15001|     Rate/Coupon:5.8|          2039.21|      2032.01|       1931.02|        1958.87|          1833.745|       1263.85|2039.0149999999999|      2073.64|       2068.55|           2080.98|          2578.355|
# |  569|2014-02-19| Sheldon Whitehouse| Child|   JPM|JPMorgan Chase & ...|Corporate Bond|        Purchase|  1001|  changed from JPJQL|           1838.9|     1833.745|       1790.15|        1783.52|           1649.65|      1339.645|          1838.925|      1866.15|       1884.88|2039.0149999999999|           2348.96|
# |  837|2017-02-22|   Patrick J Toomey| Joint|    DD|E. I. du Pont de ...|Corporate Bond|        Purchase| 15001|Originally, this ...|          2361.11|      2348.96|       2285.59|        2202.41|2095.0950000000003|      1838.925|           2360.48|      2370.34|       2397.04|          2581.215|3309.0550000000003|
# |  838|2017-02-22|   Patrick J Toomey| Joint|   TRV|The Travelers Com...|Corporate Bond|        Purchase|  1001|Originally, this ...|          2361.11|      2348.96|       2285.59|        2202.41|2095.0950000000003|      1838.925|           2360.48|      2370.34|       2397.04|          2581.215|3309.0550000000003|
# | 1019|2017-08-07|   Patrick J Toomey| Joint|     T|AT&T Inc.\nRate/C...|Corporate Bond|     Sale (Full)| 15001|Originally, this ...|          2477.14|      2476.88|        2459.5|        2401.58|           2167.49|       1910.35|           2465.38|      2447.35|        2584.7|           2621.45|           3323.17|
# | 1095|2017-01-25|   Patrick J Toomey| Joint|   BAC|Bank of America C...|Corporate Bond|        Purchase| 15001|Originally, this ...|          2288.88|      2268.87|        2261.6|        2144.06|          2069.495|      1808.995|2292.5150000000003|      2335.58|       2381.51|2572.8199999999997|           3290.13|
# | 1096|2017-01-25|   Patrick J Toomey| Joint|     T|AT&T Inc.\nRate/C...|Corporate Bond|        Purchase| 15001|Originally, this ...|          2288.88|      2268.87|        2261.6|        2144.06|          2069.495|      1808.995|2292.5150000000003|      2335.58|       2381.51|2572.8199999999997|           3290.13|
# | 2420|2016-09-30|      Gary C Peters|  Self|    VZ|Verizon Communica...|Corporate Bond|        Purchase|  1001|                  --|          2156.51|      2146.04|       2169.08|       2097.195|            2038.2|       1682.41|           2164.33|      2139.43|        2249.5|           2436.34|           2967.07|
# |11644|2016-09-08|    Susan M Collins|Spouse|   SYK|Stryker Corporati...|Corporate Bond|        Purchase| 50001|                  --|          2182.76|      2179.55|        2181.9|        2109.57|           2030.32|       1656.85|2144.9700000000003|       2168.9|       2210.72|           2437.83|           2984.38|
# |12038|2014-06-11|       Thad Cochran|Spouse|   HIG|The Hartford Fina...|Corporate Bond|     Sale (Full)| 15001|6.30% Dtd 3/4/200...|          1949.37|      1945.69|       1873.34|        1869.06|           1688.37|      1279.955|           1932.82|      1973.06|       2000.73|           2086.58|          2431.135|
# |12039|2014-06-25|       Thad Cochran|Spouse|    IR|Ingersoll-Rand Pl...|Corporate Bond|     Sale (Full)| 15001|6.875% Dtd. 3/4/2...|          1949.27|     1961.685|       1923.06|        1852.11|1691.3899999999999|       1275.74|          1958.675|      1976.35|       1992.78|2099.1549999999997|          2438.985|
# |12394|2014-06-11|       Thad Cochran|Spouse|   HIG|The Hartford Fina...|Corporate Bond|     Sale (Full)| 15001|6.30% Dtd 3/4/200...|          1949.37|      1945.69|       1873.34|        1869.06|           1688.37|      1279.955|           1932.82|      1973.06|       2000.73|           2086.58|          2431.135|
# |12395|2014-06-25|       Thad Cochran|Spouse|    IR|Ingersoll-Rand Pl...|Corporate Bond|     Sale (Full)| 15001|6.875% Dtd. 3/4/2...|          1949.27|     1961.685|       1923.06|        1852.11|1691.3899999999999|       1275.74|          1958.675|      1976.35|       1992.78|2099.1549999999997|          2438.985|
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+-------------+--------------+---------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+

# %% [markdown]
# ### 5.2. Bisecting k-means

# %%
bkm = BisectingKMeans(featuresCol="scaledFeatures")
model_bkm = bkm.fit(data_scaled)

# %%
predictions_bkm = model_bkm.transform(data_scaled)

# %%
plotting_2D(predictions_bkm)

# %%
bkm_outliers_indices = get_outliers(model_bkm,predictions_bkm,'kmeans')

# %%
bkm_outliers = data_scaled.filter(col("index").isin(bkm_outliers_indices))

# %%
results_bkm = bkm_outliers.select("index").join(training, on="index", how="inner")
results_bkm.show()
# Out:
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+------------------+--------------+------------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# |index|      Date|               Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|Amount|             Comment|current_day_price|     3_days_before|3_weeks_before|   3_months_before| 3_quarters_before|3_years_before|      3_days_after|3_weeks_after|3_months_after|  3_quarters_after|     3_years_after|
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+------------------+--------------+------------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# |   91|2014-01-31| Sheldon Whitehouse|  Self|   LOW|Lowe's Companies ...|         Stock|        Purchase|  1001|                  --|          1790.88|            1783.0|       1840.06|1761.0500000000002|            1614.4|       1289.14|           1782.68|      1841.07|       1884.39|           1964.14|           2286.01|
# |  133|2014-09-18| Sheldon Whitehouse|  Self|    EL|      The Est (NYSE)|         Stock|        Purchase|  1001|                  --|          2003.07|           1986.04|       1997.42|           1960.45|1816.6550000000002|       1214.99|2010.9099999999999|      1967.68|       1973.77|           2091.34|           2499.09|
# |  326|2014-06-18| Sheldon Whitehouse|  Self|   UNP|Union Pacific Cor...|         Stock|  Sale (Partial)|  1001|                  --|          1942.73|           1932.82|       1911.77|           1860.09|           1716.94|       1270.04|          1961.685|       1965.1|       1981.93|          2059.955|          2436.895|
# |  442|2016-08-15| Sheldon Whitehouse| Joint|   CAT|CAT-Caterpillar I...|Corporate Bond|     Sale (Full)| 15001|                  --|          2186.08|           2183.74|       2173.71|           2065.04|            2083.7|       1661.22|            2181.9|      2179.55|      2164.175|           2392.44|            2846.2|
# |  495|2014-11-13| Sheldon Whitehouse| Joint|     T|   AT&T, Inc. (NYSE)|Corporate Bond|  Sale (Partial)| 15001|     Rate/Coupon:5.8|          2039.21|           2032.01|       1931.02|           1958.87|          1833.745|       1263.85|2039.0149999999999|      2073.64|       2068.55|           2080.98|          2578.355|
# |  569|2014-02-19| Sheldon Whitehouse| Child|   JPM|JPMorgan Chase & ...|Corporate Bond|        Purchase|  1001|  changed from JPJQL|           1838.9|          1833.745|       1790.15|           1783.52|           1649.65|      1339.645|          1838.925|      1866.15|       1884.88|2039.0149999999999|           2348.96|
# | 2233|2014-01-21|        John F Reed|  Self|   CVS|CVS Caremark Corp...|         Stock|        Purchase|  1001|                  --|          1841.05|1842.6399999999999|       1842.61|           1752.27|           1585.16|       1283.46|           1826.96|      1800.45|       1865.79|1875.2649999999999|           2269.96|
# | 2420|2016-09-30|      Gary C Peters|  Self|    VZ|Verizon Communica...|Corporate Bond|        Purchase|  1001|                  --|          2156.51|           2146.04|       2169.08|          2097.195|            2038.2|       1682.41|           2164.33|      2139.43|        2249.5|           2436.34|           2967.07|
# | 7631|2013-01-24|     Jeffry L Flake| Joint|  AAPL| Apple Inc. (NASDAQ)|         Stock|  Sale (Partial)|  1001|                  --|          1494.81|1483.4650000000001|       1462.42|           1412.97|          1401.725|        1092.4|1498.8899999999999|      1520.33|       1578.78|            1745.2|1891.8400000000001|
# |11644|2016-09-08|    Susan M Collins|Spouse|   SYK|Stryker Corporati...|Corporate Bond|        Purchase| 50001|                  --|          2182.76|           2179.55|        2181.9|           2109.57|           2030.32|       1656.85|2144.9700000000003|       2168.9|       2210.72|           2437.83|           2984.38|
# |12038|2014-06-11|       Thad Cochran|Spouse|   HIG|The Hartford Fina...|Corporate Bond|     Sale (Full)| 15001|6.30% Dtd 3/4/200...|          1949.37|           1945.69|       1873.34|           1869.06|           1688.37|      1279.955|           1932.82|      1973.06|       2000.73|           2086.58|          2431.135|
# |12039|2014-06-25|       Thad Cochran|Spouse|    IR|Ingersoll-Rand Pl...|Corporate Bond|     Sale (Full)| 15001|6.875% Dtd. 3/4/2...|          1949.27|          1961.685|       1923.06|           1852.11|1691.3899999999999|       1275.74|          1958.675|      1976.35|       1992.78|2099.1549999999997|          2438.985|
# |12394|2014-06-11|       Thad Cochran|Spouse|   HIG|The Hartford Fina...|Corporate Bond|     Sale (Full)| 15001|6.30% Dtd 3/4/200...|          1949.37|           1945.69|       1873.34|           1869.06|           1688.37|      1279.955|           1932.82|      1973.06|       2000.73|           2086.58|          2431.135|
# |12395|2014-06-25|       Thad Cochran|Spouse|    IR|Ingersoll-Rand Pl...|Corporate Bond|     Sale (Full)| 15001|6.875% Dtd. 3/4/2...|          1949.27|          1961.685|       1923.06|           1852.11|1691.3899999999999|       1275.74|          1958.675|      1976.35|       1992.78|2099.1549999999997|          2438.985|
# |12827|2013-10-03|       Thad Cochran|  Self|   KKR|Kohlberg Kravis R...|         Stock|        Purchase|  1001|                  --|          1692.35|           1687.26|       1689.21|           1618.65|           1462.92|       1144.96|           1682.97|      1747.48|      1844.235|           1960.79|           2160.42|
# |12840|2013-06-24|       Thad Cochran|  Self|   SWK|Stanley Black & D...|         Stock|     Sale (Full)|  1001|                  --|          1588.77|           1588.62|       1631.71|           1551.69|           1433.36|        1075.1|           1606.44|      1679.59|       1716.94|           1874.53|            2092.8|
# |12850|2012-07-02|       Thad Cochran|  Self|   HCA|HCA Holdings, Inc...|         Stock|     Sale (Full)| 15001|                  --|          1362.33|           1330.12|       1325.72|           1418.98|           1144.11|       907.755|           1373.72|      1362.34|      1444.015|           1566.02|           2078.03|
# |12925|2013-10-03|       Thad Cochran|  Self|   KKR|Kohlberg Kravis R...|         Stock|        Purchase|  1001|                  --|          1692.35|           1687.26|       1689.21|           1618.65|           1462.92|       1144.96|           1682.97|      1747.48|      1844.235|           1960.79|           2160.42|
# |12938|2013-06-24|       Thad Cochran|  Self|   SWK|Stanley Black & D...|         Stock|     Sale (Full)|  1001|                  --|          1588.77|           1588.62|       1631.71|           1551.69|           1433.36|        1075.1|           1606.44|      1679.59|       1716.94|           1874.53|            2092.8|
# |12948|2012-07-02|       Thad Cochran|  Self|   HCA|HCA Holdings, Inc...|         Stock|     Sale (Full)| 15001|                  --|          1362.33|           1330.12|       1325.72|           1418.98|           1144.11|       907.755|           1373.72|      1362.34|      1444.015|           1566.02|           2078.03|
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+------------------+--------------+------------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### 5.3. Gaussian Mixture Model (GMM)

# %%
gmm = GaussianMixture(featuresCol="scaledFeatures",k=3)
model_gmm = gmm.fit(data_scaled)

# %%
predictions_gmm = model_gmm.transform(data_scaled)

# %%
plotting_2D(predictions_gmm)

# %%
gmm_outliers_indices = get_outliers(model_gmm,predictions_gmm,'gmm')

# %%
gmm_outliers = data_scaled.filter(col("index").isin(gmm_outliers_indices))

# %%
results_gmm = gmm_outliers.select("index").join(training, on="index", how="inner")
results_gmm.show()
# Out:
# +-----+----------+--------------------+------+------+--------------------+----------+----------------+------+--------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------+-------------+------------------+------------------+-----------------+
# |index|      Date|                Name| Owner|Ticker|          Asset_Name|Asset_Type|Transaction_Type|Amount|             Comment|current_day_price|     3_days_before|    3_weeks_before|   3_months_before| 3_quarters_before|    3_years_before|3_days_after|3_weeks_after|    3_months_after|  3_quarters_after|    3_years_after|
# +-----+----------+--------------------+------+------+--------------------+----------+----------------+------+--------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------+-------------+------------------+------------------+-----------------+
# | 1645|2018-08-20|         Pat Roberts| Joint|   XOM|Exxon Mobil Corpo...|     Stock|        Purchase|  1001|                  Jt|          2853.93|           2838.32|            2819.0|           2738.34|          2600.365|           2034.08|     2860.29|      2881.39|           2724.64|            2858.6|          4382.44|
# | 4818|2018-04-20|   David A Perdue Jr| Joint|   CLX|  The Clorox Company|     Stock|        Purchase|  1001|                  --|          2692.56|           2692.74|           2623.93|           2805.88|           2472.04|           2102.82|      2675.4|       2722.7|           2809.37|            2585.1|           4179.8|
# |  392|2018-05-07|  Sheldon Whitehouse| Joint|    CB|       Chubb Limited|     Stock|        Purchase|  1001|                  --|          2680.34|           2621.45|            2670.1|           2614.78|           2465.38|           2092.13|     2705.02|     2714.355|          2834.955|           2702.32|          4169.14|
# | 7168|2016-02-24|      James M Inhofe|  Self|   SYF| Synchrony Financial|     Stock|        Purchase| 50001|                  --|          1917.56|1920.5900000000001|           1907.07|2089.0600000000004|2114.6499999999996|           1509.01|     1951.04|      2014.24|           2052.65|           2186.64|          2792.51|
# | 1507|2018-06-22|         Pat Roberts|Spouse|  AMZN|    Amazon.com, Inc.|     Stock|     Sale (Full)| 15001|                   R|          2760.79|           2752.01|            2718.7|2633.0299999999997|           2499.39|           2123.16|     2742.94|      2796.93|           2919.73|           2840.76|           4173.4|
# | 7530|2018-03-16|         Dean Heller|Spouse|  AAPL|           APPLE INC|     Stock|        Purchase|  1001|20% Share in Brom...|          2750.57|           2792.31|            2715.8|          2673.275|           2442.55|           2080.59|     2741.38|      2645.82|           2783.21|           2664.44|          3942.96|
# | 4364|2018-09-10|   David A Perdue Jr| Joint|   OKE|         ONEOK, Inc.|     Stock|  Sale (Partial)|  1001|                  --|          2881.39|           2868.26|           2853.93|            2785.6|           2665.87|           1951.45|     2896.85|      2926.29|2661.0600000000004|           2852.87|          4513.02|
# | 5513|2018-01-16|   David A Perdue Jr| Joint|   XOM|Exxon Mobil Corpo...|     Stock|        Purchase| 15001|                  --|          2798.96|2784.5699999999997|           2679.09|           2562.87|           2354.74|          2006.505|      2802.6|      2614.78|            2670.1|          2767.185|          3788.73|
# | 7576|2018-03-16|         Dean Heller|Spouse|  EBAY|            EBAY INC|     Stock|        Purchase|  1001|20% Share in Brom...|          2750.57|           2792.31|            2715.8|          2673.275|           2442.55|           2080.59|     2741.38|      2645.82|           2783.21|           2664.44|          3942.96|
# | 2924|2018-07-19|   David A Perdue Jr| Joint|  SBUX|Starbucks Corpora...|     Stock|     Sale (Full)| 15001|                  --|          2809.37|           2797.36|           2698.69|           2692.56|2572.8199999999997|           2126.85|     2801.86|      2857.19|           2811.67|           2908.32|         4331.915|
# | 6301|2018-06-01| A. Mitchell McCo...|Spouse|   WFC|Wells Fargo & Com...|     Stock|        Purchase|  1001|Dividend Reinvest...|           2718.7|           2705.11|            2722.7|          2669.975|          2472.385|           2110.41|     2741.67|      2760.79|           2908.94|           2792.36|         4213.645|
# | 7584|2018-03-16|         Dean Heller|Spouse|   JPM| JPMORGAN CHASE & CO|     Stock|        Purchase|  1001|20% Share in Brom...|          2750.57|           2792.31|            2715.8|          2673.275|           2442.55|           2080.59|     2741.38|      2645.82|           2783.21|           2664.44|          3942.96|
# | 7567|2018-03-16|         Dean Heller|Spouse|   AXP|AMER EXPRESS COMPANY|     Stock|        Purchase|  1001|20% Share in Brom...|          2750.57|           2792.31|            2715.8|          2673.275|           2442.55|           2080.59|     2741.38|      2645.82|           2783.21|           2664.44|          3942.96|
# | 3028|2018-08-16|   David A Perdue Jr| Joint|   BAC|Bank of America C...|     Stock|  Sale (Partial)|  1001|                  --|          2831.44|           2835.46|           2835.49|           2717.35|          2581.215|            2089.7|    2846.125|      2888.64|            2737.9|           2840.19|         4463.245|
# | 2914|2018-07-13|   David A Perdue Jr| Joint|   LYV|Live Nation Enter...|     Stock|  Sale (Partial)|  1001|                  --|          2796.93|           2788.56|           2760.79|            2673.5|           2555.57|           2099.72|     2797.36|      2829.62|           2776.87|           2886.58|          4372.41|
# |15584|2015-12-11|           Roy Blunt|Spouse|  CSCO|                CSCO|     Stock|     Sale (Full)|  1001|                  --|          2047.27|           2073.39|           2082.82|          1957.255|           2055.35|           1418.55|     2013.37|     2049.395|           1990.97|           2181.61|          2630.86|
# | 1787|2018-02-05|         Pat Roberts|Spouse|  AMZN|    Amazon.com, Inc.|     Stock|     Sale (Full)|  1001|                   R|          2741.06|           2808.92|2784.5699999999997|           2592.11|           2394.84|           2062.28|     2685.01|      2757.37|          2650.895|           2745.45|          3836.66|
# | 4799|2018-06-28|   David A Perdue Jr| Joint|   CZR|Caesars Entertain...|     Stock|        Purchase|  1001|                  --|          2698.69|           2742.94|           2774.84|           2623.93|           2515.58|           2098.63|     2716.04|      2809.37|           2916.98|           2796.01|4279.674999999999|
# | 7222|2018-06-07|         John Hoeven|  Self|   CVS|CVS Health Corpor...|     Stock|        Purchase| 50001|                  --|          2774.84|           2741.67|           2719.71|           2752.91|          2468.385|           2092.34|     2773.01|      2698.69|           2891.59|           2814.37|         4217.695|
# | 6911|2016-01-19|    Angus S King Jr.|Spouse|    CB|       Chubb Limited|     Stock|        Exchange|  1001|MANDATORY MERGER ...|          1888.66|           1902.67|           2060.54|           2033.47|            2112.8|1483.4650000000001|      1877.4|      1848.46|           2078.83|2136.3149999999996|          2651.27|
# +-----+----------+--------------------+------+------+--------------------+----------+----------------+------+--------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------+-------------+------------------+------------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# checking and investigating the outliers

# %% [markdown]
# ## 6. Result : Suspicious transaction detected

# %% [markdown]
# 1. kmeans:
#
#     kmeans found a few outliers that we needed to investigating.
#
#     the outliers was points that wasn't behaved in the same patern and had different interesting thoughts.
#     some of them shows that some stocks had a huge increasement after a purchase by a senators right after the purchase and some of them shows an increasement after 3 months
#
# 2. Bisecting k-means:
#
#   the model shows only transactions as suspicious when it was huge increasement right after the purchase in the stock but not in the long term
#
# 3. GMM:
#
#   the model find points as outliers only points that shows increasements in the stocks only for moderate and long term

# %% [markdown]
# final thoughts:
#
#   It was huge different between the results of the different models and how they determine which point is an ouliers or not. Although we extract features that help the model to generalise what is considered to be anomaly for short/moderate/long term, it seems like each model focused on his own path.
#
#   It seems like the best way to get the most accurate and general results is to investigate a methods that assemble couple of models or using advanced models of deep learning like cnn/transformers and ect

# %%
training.show()
# Out:
# +----------+-----+-------------------+------+------+--------------------+----------+----------------+------+-------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# |      Date|Index|               Name| Owner|Ticker|          Asset_Name|Asset_Type|Transaction_Type|Amount|Comment|current_day_price|3_days_before|3_weeks_before|   3_months_before|3_quarters_before|3_years_before|3_days_after|3_weeks_after|    3_months_after|3_quarters_after|3_years_after|
# +----------+-----+-------------------+------+------+--------------------+----------+----------------+------+-------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# |2018-08-10| 3022|  David A Perdue Jr| Joint|   CZR|Caesars Entertain...|     Stock|        Purchase|  1001|     --|           2838.9|      2855.92|       2804.55|          2730.585|          2576.53|       2102.66|     2835.46|      2898.37|           2806.38|         2913.03|      4437.77|
# |2018-08-10| 3021|  David A Perdue Jr| Joint|   MOS|  The Mosaic Company|     Stock|  Sale (Partial)|  1001|     --|           2838.9|      2855.92|       2804.55|          2730.585|          2576.53|       2102.66|     2835.46|      2898.37|           2806.38|         2913.03|      4437.77|
# |2016-03-01|12797|       Thad Cochran|  Self|   MET|       MetLife, Inc.|     Stock|        Purchase| 15001|     --|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |2016-03-01|  273| Sheldon Whitehouse| Child|     V|           Visa Inc.|     Stock|  Sale (Partial)|  1001|     --|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |2016-03-01|  272| Sheldon Whitehouse| Child|   CVS|CVS Health Corpor...|     Stock|  Sale (Partial)|  1001|     --|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |2016-03-01| 3659|  David A Perdue Jr| Joint|    GE|Cabela's Incorpor...|     Stock|  Sale (Partial)|  1001|     --|          1937.09|      1951.04|       1848.46|           2101.71|          2095.09|       1516.44|     1994.01|      2048.64|2095.0950000000003|         2208.24|      2798.22|
# |2017-09-11| 5393|  David A Perdue Jr| Joint|   MRK|   Merck & Co., Inc.|     Stock|        Purchase|  1001|     --|          2474.52|      2462.25|        2425.5|           2434.15|          2253.77|       1996.74|     2494.56|       2521.2|            2649.2|         2765.84|      3412.56|
# |2017-08-11| 2027|        Pat Roberts|Spouse|    BA|BA-The Boeing Com...|     Stock|        Purchase|  1001|    sep|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# |2017-08-11| 5481|  David A Perdue Jr| Joint|    RF|Regions Financial...|     Stock|        Purchase|  1001|     --|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# |2017-08-11| 5480|  David A Perdue Jr| Joint|   WMT|Wal-Mart Stores, ...|     Stock|  Sale (Partial)| 15001|     --|          2441.04|      2478.35|        2467.4|           2393.21|          2165.64|       1935.73|     2454.96|      2474.42|            2584.0|         2670.26|      3356.04|
# |2015-03-09| 1845|        Pat Roberts|Spouse|  AMZN|Amazon.com Inc. (...|     Stock|     Sale (Full)| 15001|      R|          2072.25|      2100.91|      2092.625|           2056.55|          1943.35|       1365.97|      2041.1|      2064.11|          2093.715|         2051.24|      2732.75|
# |2015-03-06| 1844|        Pat Roberts|Spouse|  SBUX|Starbucks Corpora...|     Stock|        Purchase|  1001|      R|          2100.91|      2115.76|       2088.78|2073.8100000000004|          1948.97|       1363.63|     2072.25|      2055.78|           2112.35|         2082.93|      2681.06|
# |2015-03-06| 1843|        Pat Roberts|Spouse|  COST|Costco Wholesale ...|     Stock|        Purchase|  1001|      R|          2100.91|      2115.76|       2088.78|2073.8100000000004|          1948.97|       1363.63|     2072.25|      2055.78|           2112.35|         2082.93|      2681.06|
# |2018-06-06|  556| Sheldon Whitehouse|Spouse|   WMT|        Walmart Inc.|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  555| Sheldon Whitehouse|Spouse|  PYPL|PayPal Holdings, ...|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  554| Sheldon Whitehouse|Spouse|  LRCX|Lam Research Corp...|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  553| Sheldon Whitehouse|Spouse|    GS|The Goldman Sachs...|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  552| Sheldon Whitehouse|Spouse|   DAL|Delta Air Lines, ...|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  551| Sheldon Whitehouse|Spouse|     C|      Citigroup Inc.|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# |2018-06-06|  550| Sheldon Whitehouse|Spouse|    BA|  The Boeing Company|     Stock|        Purchase|  1001|     --|          2753.25|     2730.185|       2712.62|           2732.75|         2468.385|      2093.715|     2773.01|      2728.45|           2896.96|        2806.295|     4217.695|
# +----------+-----+-------------------+------+------+--------------------+----------+----------------+------+-------+-----------------+-------------+--------------+------------------+-----------------+--------------+------------+-------------+------------------+----------------+-------------+
# only showing top 20 rows

# %%
results_kmeans.show()
# Out:
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+-------------+--------------+---------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# |index|      Date|               Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|Amount|             Comment|current_day_price|3_days_before|3_weeks_before|3_months_before| 3_quarters_before|3_years_before|      3_days_after|3_weeks_after|3_months_after|  3_quarters_after|     3_years_after|
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+-------------+--------------+---------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# |  442|2016-08-15| Sheldon Whitehouse| Joint|   CAT|CAT-Caterpillar I...|Corporate Bond|     Sale (Full)| 15001|                  --|          2186.08|      2183.74|       2173.71|        2065.04|            2083.7|       1661.22|            2181.9|      2179.55|      2164.175|           2392.44|            2846.2|
# |  495|2014-11-13| Sheldon Whitehouse| Joint|     T|   AT&T, Inc. (NYSE)|Corporate Bond|  Sale (Partial)| 15001|     Rate/Coupon:5.8|          2039.21|      2032.01|       1931.02|        1958.87|          1833.745|       1263.85|2039.0149999999999|      2073.64|       2068.55|           2080.98|          2578.355|
# |  569|2014-02-19| Sheldon Whitehouse| Child|   JPM|JPMorgan Chase & ...|Corporate Bond|        Purchase|  1001|  changed from JPJQL|           1838.9|     1833.745|       1790.15|        1783.52|           1649.65|      1339.645|          1838.925|      1866.15|       1884.88|2039.0149999999999|           2348.96|
# |  837|2017-02-22|   Patrick J Toomey| Joint|    DD|E. I. du Pont de ...|Corporate Bond|        Purchase| 15001|Originally, this ...|          2361.11|      2348.96|       2285.59|        2202.41|2095.0950000000003|      1838.925|           2360.48|      2370.34|       2397.04|          2581.215|3309.0550000000003|
# |  838|2017-02-22|   Patrick J Toomey| Joint|   TRV|The Travelers Com...|Corporate Bond|        Purchase|  1001|Originally, this ...|          2361.11|      2348.96|       2285.59|        2202.41|2095.0950000000003|      1838.925|           2360.48|      2370.34|       2397.04|          2581.215|3309.0550000000003|
# | 1019|2017-08-07|   Patrick J Toomey| Joint|     T|AT&T Inc.\nRate/C...|Corporate Bond|     Sale (Full)| 15001|Originally, this ...|          2477.14|      2476.88|        2459.5|        2401.58|           2167.49|       1910.35|           2465.38|      2447.35|        2584.7|           2621.45|           3323.17|
# | 1095|2017-01-25|   Patrick J Toomey| Joint|   BAC|Bank of America C...|Corporate Bond|        Purchase| 15001|Originally, this ...|          2288.88|      2268.87|        2261.6|        2144.06|          2069.495|      1808.995|2292.5150000000003|      2335.58|       2381.51|2572.8199999999997|           3290.13|
# | 1096|2017-01-25|   Patrick J Toomey| Joint|     T|AT&T Inc.\nRate/C...|Corporate Bond|        Purchase| 15001|Originally, this ...|          2288.88|      2268.87|        2261.6|        2144.06|          2069.495|      1808.995|2292.5150000000003|      2335.58|       2381.51|2572.8199999999997|           3290.13|
# | 2420|2016-09-30|      Gary C Peters|  Self|    VZ|Verizon Communica...|Corporate Bond|        Purchase|  1001|                  --|          2156.51|      2146.04|       2169.08|       2097.195|            2038.2|       1682.41|           2164.33|      2139.43|        2249.5|           2436.34|           2967.07|
# |11644|2016-09-08|    Susan M Collins|Spouse|   SYK|Stryker Corporati...|Corporate Bond|        Purchase| 50001|                  --|          2182.76|      2179.55|        2181.9|        2109.57|           2030.32|       1656.85|2144.9700000000003|       2168.9|       2210.72|           2437.83|           2984.38|
# |12038|2014-06-11|       Thad Cochran|Spouse|   HIG|The Hartford Fina...|Corporate Bond|     Sale (Full)| 15001|6.30% Dtd 3/4/200...|          1949.37|      1945.69|       1873.34|        1869.06|           1688.37|      1279.955|           1932.82|      1973.06|       2000.73|           2086.58|          2431.135|
# |12039|2014-06-25|       Thad Cochran|Spouse|    IR|Ingersoll-Rand Pl...|Corporate Bond|     Sale (Full)| 15001|6.875% Dtd. 3/4/2...|          1949.27|     1961.685|       1923.06|        1852.11|1691.3899999999999|       1275.74|          1958.675|      1976.35|       1992.78|2099.1549999999997|          2438.985|
# |12394|2014-06-11|       Thad Cochran|Spouse|   HIG|The Hartford Fina...|Corporate Bond|     Sale (Full)| 15001|6.30% Dtd 3/4/200...|          1949.37|      1945.69|       1873.34|        1869.06|           1688.37|      1279.955|           1932.82|      1973.06|       2000.73|           2086.58|          2431.135|
# |12395|2014-06-25|       Thad Cochran|Spouse|    IR|Ingersoll-Rand Pl...|Corporate Bond|     Sale (Full)| 15001|6.875% Dtd. 3/4/2...|          1949.27|     1961.685|       1923.06|        1852.11|1691.3899999999999|       1275.74|          1958.675|      1976.35|       1992.78|2099.1549999999997|          2438.985|
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+-------------+--------------+---------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+

# %%
results_bkm.show()
# Out:
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+------------------+--------------+------------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# |index|      Date|               Name| Owner|Ticker|          Asset_Name|    Asset_Type|Transaction_Type|Amount|             Comment|current_day_price|     3_days_before|3_weeks_before|   3_months_before| 3_quarters_before|3_years_before|      3_days_after|3_weeks_after|3_months_after|  3_quarters_after|     3_years_after|
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+------------------+--------------+------------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# |   91|2014-01-31| Sheldon Whitehouse|  Self|   LOW|Lowe's Companies ...|         Stock|        Purchase|  1001|                  --|          1790.88|            1783.0|       1840.06|1761.0500000000002|            1614.4|       1289.14|           1782.68|      1841.07|       1884.39|           1964.14|           2286.01|
# |  133|2014-09-18| Sheldon Whitehouse|  Self|    EL|      The Est (NYSE)|         Stock|        Purchase|  1001|                  --|          2003.07|           1986.04|       1997.42|           1960.45|1816.6550000000002|       1214.99|2010.9099999999999|      1967.68|       1973.77|           2091.34|           2499.09|
# |  326|2014-06-18| Sheldon Whitehouse|  Self|   UNP|Union Pacific Cor...|         Stock|  Sale (Partial)|  1001|                  --|          1942.73|           1932.82|       1911.77|           1860.09|           1716.94|       1270.04|          1961.685|       1965.1|       1981.93|          2059.955|          2436.895|
# |  442|2016-08-15| Sheldon Whitehouse| Joint|   CAT|CAT-Caterpillar I...|Corporate Bond|     Sale (Full)| 15001|                  --|          2186.08|           2183.74|       2173.71|           2065.04|            2083.7|       1661.22|            2181.9|      2179.55|      2164.175|           2392.44|            2846.2|
# |  495|2014-11-13| Sheldon Whitehouse| Joint|     T|   AT&T, Inc. (NYSE)|Corporate Bond|  Sale (Partial)| 15001|     Rate/Coupon:5.8|          2039.21|           2032.01|       1931.02|           1958.87|          1833.745|       1263.85|2039.0149999999999|      2073.64|       2068.55|           2080.98|          2578.355|
# |  569|2014-02-19| Sheldon Whitehouse| Child|   JPM|JPMorgan Chase & ...|Corporate Bond|        Purchase|  1001|  changed from JPJQL|           1838.9|          1833.745|       1790.15|           1783.52|           1649.65|      1339.645|          1838.925|      1866.15|       1884.88|2039.0149999999999|           2348.96|
# | 2233|2014-01-21|        John F Reed|  Self|   CVS|CVS Caremark Corp...|         Stock|        Purchase|  1001|                  --|          1841.05|1842.6399999999999|       1842.61|           1752.27|           1585.16|       1283.46|           1826.96|      1800.45|       1865.79|1875.2649999999999|           2269.96|
# | 2420|2016-09-30|      Gary C Peters|  Self|    VZ|Verizon Communica...|Corporate Bond|        Purchase|  1001|                  --|          2156.51|           2146.04|       2169.08|          2097.195|            2038.2|       1682.41|           2164.33|      2139.43|        2249.5|           2436.34|           2967.07|
# | 7631|2013-01-24|     Jeffry L Flake| Joint|  AAPL| Apple Inc. (NASDAQ)|         Stock|  Sale (Partial)|  1001|                  --|          1494.81|1483.4650000000001|       1462.42|           1412.97|          1401.725|        1092.4|1498.8899999999999|      1520.33|       1578.78|            1745.2|1891.8400000000001|
# |11644|2016-09-08|    Susan M Collins|Spouse|   SYK|Stryker Corporati...|Corporate Bond|        Purchase| 50001|                  --|          2182.76|           2179.55|        2181.9|           2109.57|           2030.32|       1656.85|2144.9700000000003|       2168.9|       2210.72|           2437.83|           2984.38|
# |12038|2014-06-11|       Thad Cochran|Spouse|   HIG|The Hartford Fina...|Corporate Bond|     Sale (Full)| 15001|6.30% Dtd 3/4/200...|          1949.37|           1945.69|       1873.34|           1869.06|           1688.37|      1279.955|           1932.82|      1973.06|       2000.73|           2086.58|          2431.135|
# |12039|2014-06-25|       Thad Cochran|Spouse|    IR|Ingersoll-Rand Pl...|Corporate Bond|     Sale (Full)| 15001|6.875% Dtd. 3/4/2...|          1949.27|          1961.685|       1923.06|           1852.11|1691.3899999999999|       1275.74|          1958.675|      1976.35|       1992.78|2099.1549999999997|          2438.985|
# |12394|2014-06-11|       Thad Cochran|Spouse|   HIG|The Hartford Fina...|Corporate Bond|     Sale (Full)| 15001|6.30% Dtd 3/4/200...|          1949.37|           1945.69|       1873.34|           1869.06|           1688.37|      1279.955|           1932.82|      1973.06|       2000.73|           2086.58|          2431.135|
# |12395|2014-06-25|       Thad Cochran|Spouse|    IR|Ingersoll-Rand Pl...|Corporate Bond|     Sale (Full)| 15001|6.875% Dtd. 3/4/2...|          1949.27|          1961.685|       1923.06|           1852.11|1691.3899999999999|       1275.74|          1958.675|      1976.35|       1992.78|2099.1549999999997|          2438.985|
# |12827|2013-10-03|       Thad Cochran|  Self|   KKR|Kohlberg Kravis R...|         Stock|        Purchase|  1001|                  --|          1692.35|           1687.26|       1689.21|           1618.65|           1462.92|       1144.96|           1682.97|      1747.48|      1844.235|           1960.79|           2160.42|
# |12840|2013-06-24|       Thad Cochran|  Self|   SWK|Stanley Black & D...|         Stock|     Sale (Full)|  1001|                  --|          1588.77|           1588.62|       1631.71|           1551.69|           1433.36|        1075.1|           1606.44|      1679.59|       1716.94|           1874.53|            2092.8|
# |12850|2012-07-02|       Thad Cochran|  Self|   HCA|HCA Holdings, Inc...|         Stock|     Sale (Full)| 15001|                  --|          1362.33|           1330.12|       1325.72|           1418.98|           1144.11|       907.755|           1373.72|      1362.34|      1444.015|           1566.02|           2078.03|
# |12925|2013-10-03|       Thad Cochran|  Self|   KKR|Kohlberg Kravis R...|         Stock|        Purchase|  1001|                  --|          1692.35|           1687.26|       1689.21|           1618.65|           1462.92|       1144.96|           1682.97|      1747.48|      1844.235|           1960.79|           2160.42|
# |12938|2013-06-24|       Thad Cochran|  Self|   SWK|Stanley Black & D...|         Stock|     Sale (Full)|  1001|                  --|          1588.77|           1588.62|       1631.71|           1551.69|           1433.36|        1075.1|           1606.44|      1679.59|       1716.94|           1874.53|            2092.8|
# |12948|2012-07-02|       Thad Cochran|  Self|   HCA|HCA Holdings, Inc...|         Stock|     Sale (Full)| 15001|                  --|          1362.33|           1330.12|       1325.72|           1418.98|           1144.11|       907.755|           1373.72|      1362.34|      1444.015|           1566.02|           2078.03|
# +-----+----------+-------------------+------+------+--------------------+--------------+----------------+------+--------------------+-----------------+------------------+--------------+------------------+------------------+--------------+------------------+-------------+--------------+------------------+------------------+
# only showing top 20 rows

# %%
results_gmm.show()
# Out:
# +-----+----------+--------------------+------+------+--------------------+----------+----------------+------+--------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------+-------------+------------------+------------------+-----------------+
# |index|      Date|                Name| Owner|Ticker|          Asset_Name|Asset_Type|Transaction_Type|Amount|             Comment|current_day_price|     3_days_before|    3_weeks_before|   3_months_before| 3_quarters_before|    3_years_before|3_days_after|3_weeks_after|    3_months_after|  3_quarters_after|    3_years_after|
# +-----+----------+--------------------+------+------+--------------------+----------+----------------+------+--------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------+-------------+------------------+------------------+-----------------+
# | 1645|2018-08-20|         Pat Roberts| Joint|   XOM|Exxon Mobil Corpo...|     Stock|        Purchase|  1001|                  Jt|          2853.93|           2838.32|            2819.0|           2738.34|          2600.365|           2034.08|     2860.29|      2881.39|           2724.64|            2858.6|          4382.44|
# | 4818|2018-04-20|   David A Perdue Jr| Joint|   CLX|  The Clorox Company|     Stock|        Purchase|  1001|                  --|          2692.56|           2692.74|           2623.93|           2805.88|           2472.04|           2102.82|      2675.4|       2722.7|           2809.37|            2585.1|           4179.8|
# |  392|2018-05-07|  Sheldon Whitehouse| Joint|    CB|       Chubb Limited|     Stock|        Purchase|  1001|                  --|          2680.34|           2621.45|            2670.1|           2614.78|           2465.38|           2092.13|     2705.02|     2714.355|          2834.955|           2702.32|          4169.14|
# | 7168|2016-02-24|      James M Inhofe|  Self|   SYF| Synchrony Financial|     Stock|        Purchase| 50001|                  --|          1917.56|1920.5900000000001|           1907.07|2089.0600000000004|2114.6499999999996|           1509.01|     1951.04|      2014.24|           2052.65|           2186.64|          2792.51|
# | 1507|2018-06-22|         Pat Roberts|Spouse|  AMZN|    Amazon.com, Inc.|     Stock|     Sale (Full)| 15001|                   R|          2760.79|           2752.01|            2718.7|2633.0299999999997|           2499.39|           2123.16|     2742.94|      2796.93|           2919.73|           2840.76|           4173.4|
# | 7530|2018-03-16|         Dean Heller|Spouse|  AAPL|           APPLE INC|     Stock|        Purchase|  1001|20% Share in Brom...|          2750.57|           2792.31|            2715.8|          2673.275|           2442.55|           2080.59|     2741.38|      2645.82|           2783.21|           2664.44|          3942.96|
# | 4364|2018-09-10|   David A Perdue Jr| Joint|   OKE|         ONEOK, Inc.|     Stock|  Sale (Partial)|  1001|                  --|          2881.39|           2868.26|           2853.93|            2785.6|           2665.87|           1951.45|     2896.85|      2926.29|2661.0600000000004|           2852.87|          4513.02|
# | 5513|2018-01-16|   David A Perdue Jr| Joint|   XOM|Exxon Mobil Corpo...|     Stock|        Purchase| 15001|                  --|          2798.96|2784.5699999999997|           2679.09|           2562.87|           2354.74|          2006.505|      2802.6|      2614.78|            2670.1|          2767.185|          3788.73|
# | 7576|2018-03-16|         Dean Heller|Spouse|  EBAY|            EBAY INC|     Stock|        Purchase|  1001|20% Share in Brom...|          2750.57|           2792.31|            2715.8|          2673.275|           2442.55|           2080.59|     2741.38|      2645.82|           2783.21|           2664.44|          3942.96|
# | 2924|2018-07-19|   David A Perdue Jr| Joint|  SBUX|Starbucks Corpora...|     Stock|     Sale (Full)| 15001|                  --|          2809.37|           2797.36|           2698.69|           2692.56|2572.8199999999997|           2126.85|     2801.86|      2857.19|           2811.67|           2908.32|         4331.915|
# | 6301|2018-06-01| A. Mitchell McCo...|Spouse|   WFC|Wells Fargo & Com...|     Stock|        Purchase|  1001|Dividend Reinvest...|           2718.7|           2705.11|            2722.7|          2669.975|          2472.385|           2110.41|     2741.67|      2760.79|           2908.94|           2792.36|         4213.645|
# | 7584|2018-03-16|         Dean Heller|Spouse|   JPM| JPMORGAN CHASE & CO|     Stock|        Purchase|  1001|20% Share in Brom...|          2750.57|           2792.31|            2715.8|          2673.275|           2442.55|           2080.59|     2741.38|      2645.82|           2783.21|           2664.44|          3942.96|
# | 7567|2018-03-16|         Dean Heller|Spouse|   AXP|AMER EXPRESS COMPANY|     Stock|        Purchase|  1001|20% Share in Brom...|          2750.57|           2792.31|            2715.8|          2673.275|           2442.55|           2080.59|     2741.38|      2645.82|           2783.21|           2664.44|          3942.96|
# | 3028|2018-08-16|   David A Perdue Jr| Joint|   BAC|Bank of America C...|     Stock|  Sale (Partial)|  1001|                  --|          2831.44|           2835.46|           2835.49|           2717.35|          2581.215|            2089.7|    2846.125|      2888.64|            2737.9|           2840.19|         4463.245|
# | 2914|2018-07-13|   David A Perdue Jr| Joint|   LYV|Live Nation Enter...|     Stock|  Sale (Partial)|  1001|                  --|          2796.93|           2788.56|           2760.79|            2673.5|           2555.57|           2099.72|     2797.36|      2829.62|           2776.87|           2886.58|          4372.41|
# |15584|2015-12-11|           Roy Blunt|Spouse|  CSCO|                CSCO|     Stock|     Sale (Full)|  1001|                  --|          2047.27|           2073.39|           2082.82|          1957.255|           2055.35|           1418.55|     2013.37|     2049.395|           1990.97|           2181.61|          2630.86|
# | 1787|2018-02-05|         Pat Roberts|Spouse|  AMZN|    Amazon.com, Inc.|     Stock|     Sale (Full)|  1001|                   R|          2741.06|           2808.92|2784.5699999999997|           2592.11|           2394.84|           2062.28|     2685.01|      2757.37|          2650.895|           2745.45|          3836.66|
# | 4799|2018-06-28|   David A Perdue Jr| Joint|   CZR|Caesars Entertain...|     Stock|        Purchase|  1001|                  --|          2698.69|           2742.94|           2774.84|           2623.93|           2515.58|           2098.63|     2716.04|      2809.37|           2916.98|           2796.01|4279.674999999999|
# | 7222|2018-06-07|         John Hoeven|  Self|   CVS|CVS Health Corpor...|     Stock|        Purchase| 50001|                  --|          2774.84|           2741.67|           2719.71|           2752.91|          2468.385|           2092.34|     2773.01|      2698.69|           2891.59|           2814.37|         4217.695|
# | 6911|2016-01-19|    Angus S King Jr.|Spouse|    CB|       Chubb Limited|     Stock|        Exchange|  1001|MANDATORY MERGER ...|          1888.66|           1902.67|           2060.54|           2033.47|            2112.8|1483.4650000000001|      1877.4|      1848.46|           2078.83|2136.3149999999996|          2651.27|
# +-----+----------+--------------------+------+------+--------------------+----------+----------------+------+--------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------+-------------+------------------+------------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ![Screenshot 2024-07-14 at 14.51.28.png](data:image/png;base64,...)![Screenshot 2024-07-14 at 14.45.53.png](data:image/png;base64,...)![Screenshot 2024-07-14 at 14.42.21.png](data:image/png;base64,...)
